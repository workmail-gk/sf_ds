# %% [markdown]
# ### КАКОЙ КЕЙС РЕШАЕМ?
#
# Представим, что работаем дата-сайентистом в компании Booking. Одна из проблем компании — это нечестные отели, которые накручивают себе рейтинг. Одним из способов обнаружения таких отелей является построение модели, которая предсказывает рейтинг отеля. Если предсказания модели сильно отличаются от фактического результата, то, возможно, отель ведёт себя нечестно, и его стоит проверить.

# %%
from datetime import datetime as dt
import pytz
tz = pytz.timezone('Asia/Almaty')
start_time = dt.now(tz).strftime("%H:%M:%S")
start_time = dt.strptime(start_time,"%H:%M:%S")

# %%
# %%capture

# установка дополнительных библиотек:
# !pip install Afinn
# !pip install nltk[twitter] 
# !pip install -U lightautoml

# инструменты анализа и обработки данных
import pandas as pd
import numpy as np
import re
import geopy.distance
from scipy import stats
from category_encoders import  OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import f_classif

# инструменты для лингвистического анализа:
import string
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob, Blobber
from textblob.sentiments import NaiveBayesAnalyzer
from afinn import Afinn
nltk.download('vader_lexicon')

# инструменты для визуализации:
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# параметры отображения содержимого на экране:
from IPython.display import display
from termcolor import colored
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.3f}'.format)
pd.set_option('display.max_rows', 200)

# инструменты для построения модели:
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from sklearn.metrics import mean_absolute_percentage_error

# LightAutoML presets, task and report generation
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task

# фиксируем необходимые переменные и версию пакетов, чтобы эксперименты были воспроизводимы:
N_THREADS = 4 
N_FOLDS = 5 
RANDOM_STATE = 42 
TEST_SIZE = 0.2
TIMEOUT = 3600 
TARGET_NAME = 'reviewer_score' 

# !pip freeze > requirements.tx

# %%
# данные из соревнования
DATA_DIR = '/kaggle/input/sf-booking/'
df_train = pd.read_csv(DATA_DIR+'/hotels_train.csv') 
df_test = pd.read_csv(DATA_DIR+'hotels_test.csv') 
sample_submission = pd.read_csv(DATA_DIR+'/submission.csv')

# %%
df_train['sample'] = 1 
df_test['sample'] = 0 
df_test['reviewer_score'] = 0
hotels = df_test.append(df_train, sort=False).reset_index(drop=True)
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               515738 non-null  object
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   review_date                                 515738 non-null  object
#  3   average_score                               515738 non-null  float64
#  4   hotel_name                                  515738 non-null  object
#  5   reviewer_nationality                        515738 non-null  object
#  6   negative_review                             515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   positive_review                             515738 non-null  object
#  10  review_total_positive_word_counts           515738 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  12  tags                                        515738 non-null  object
#  13  days_since_review                           515738 non-null  object
#  14  lat                                         512470 non-null  float64
#  15  lng                                         512470 non-null  float64
#  16  sample                                      515738 non-null  int64
#  17  reviewer_score                              515738 non-null  float64
# dtypes: float64(4), int64(6), object(8)
# memory usage: 70.8+ MB

# %% [markdown]
# # 0. Исходные данные:

# %%
hotels = df_test.append(df_train, sort=False).reset_index(drop=True)
display(hotels.info())

hotels_isnull = hotels.isnull().sum()
print(f'\nСтолбцы с явными пропусками данных:\n{hotels_isnull[hotels_isnull > 0]}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515738 entries, 0 to 515737
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               515738 non-null  object
#  1   additional_number_of_scoring                515738 non-null  int64
#  2   review_date                                 515738 non-null  object
#  3   average_score                               515738 non-null  float64
#  4   hotel_name                                  515738 non-null  object
#  5   reviewer_nationality                        515738 non-null  object
#  6   negative_review                             515738 non-null  object
#  7   review_total_negative_word_counts           515738 non-null  int64
#  8   total_number_of_reviews                     515738 non-null  int64
#  9   positive_review                             515738 non-null  object
#  10  review_total_positive_word_counts           515738 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  515738 non-null  int64
#  12  tags                                        515738 non-null  object
#  13  days_since_review                           515738 non-null  object
#  14  lat                                         512470 non-null  float64
#  15  lng                                         512470 non-null  float64
#  16  sample                                      515738 non-null  int64
#  17  reviewer_score                              515738 non-null  float64
# dtypes: float64(4), int64(6), object(8)
# memory usage: 70.8+ MB
# None
# Столбцы с явными пропусками данных:
# lat    3268
# lng    3268
# dtype: int64

# %% [markdown]
# # 1. Исследование и проектирование признаков (FEATURE ENGINEERING):

# %% [markdown]
# ## 1.1 ГРУППА ПРИЗНАКОВ ХАРКТЕРИЗУЮЩИХ ОТЕЛЬ
# - Название и Адрес отеля ('hotel_address', 'hotel_name')
# - Координаты отеля - Географическая широта и долгота отеля ('lat', 'lng')
# - Средний балл отеля за последний год ('average_score')
# - Общее количество отзывов об отеле ('total_number_of_reviews')
# - Общее количество оценок без отзывов ('additional_number_of_scoring')

# %% [markdown]
# ### <span style="color:blue">НАЗВАНИЕ ОТЕЛЯ ('hotel_name')</span>

# %%
# исследуем данные о названии на наличие пропусков и дубликатов:
pivot_n = hotels[['hotel_address', 'hotel_name']].groupby(
    by='hotel_name'
).nunique()

name_rep = pivot_n[pivot_n['hotel_address'] != 1].index.to_list()
mask = hotels['hotel_name'].isin(name_rep)
addresses_rep = hotels[mask][['hotel_name', 'hotel_address']].value_counts()

print(colored('Дублирование Названия отеля:', 'green'))
display(addresses_rep)

# чтобы различать эти отели при анализе - добавим в название город:
hotels['hotel_name'] = hotels.apply(
    lambda row: (row['hotel_name'] + ' ' + row['hotel_address'].split()[-2])
    if (row['hotel_name'] in name_rep)
    else row['hotel_name'], axis=1)

print(colored('\nПроверим полученные изменения:', 'green'))
mask = hotels['hotel_name'].str.contains(name_rep[0])
display(hotels[mask]['hotel_name'].value_counts())
# Out:
# Дублирование Названия отеля:
# hotel_name    hotel_address
# Hotel Regina  Bergara 2 4 Eixample 08002 Barcelona Spain                    590
#               Rooseveltplatz 15 09 Alsergrund 1090 Vienna Austria           284
#               Via Cesare Correnti 13 Milan City Center 20123 Milan Italy     60
# dtype: int64
# Проверим полученные изменения:
# Hotel Regina Barcelona    590
# Hotel Regina Vienna       284
# Hotel Regina Milan         60
# Name: hotel_name, dtype: int64

# %% [markdown]
#     Название отеля можно использовать для обучения модели, только если его кодировать. Код названия сам по себе вряд ли может что-то сообщить. Отелей больше тысячи и числовой код скорее запутает модель из-за своей размерности, которая не несет никакой смысловой нагрузки.
#
#     Попробуем сообщить модели хоть какую-то осмысленную информацию. Название - это уникальная характеристика отеля. Отели можно отсортировать, например, по популярности (кол-во отзывов) или по рейтингу (средний бал). Но тогда получится, что наш признак будет дублировать по смыслу или столбец с количеством отзывов, или столбец со средней оценкой.
#
#     Я скорее склоняюсь к идеи удаления этого столбца, но позже, на этапе анализа всех признаков и их влияния на целевую переменную.
#
#     А пока закодируем название, используя обе эти характеристики. Пусть у нас будут только лучшие по отзывам и достаточно популярные отели (как вариант).

# %%
# выделим топ лучших по рейтингу, с порогом в 100 отзывов:
hotels_names = hotels.groupby('hotel_name')['average_score'].agg(
    ['mean', 'count'])

mask = (hotels_names['mean'] >= 9.0) & (hotels_names['count'] >= 100)
hotels_top = hotels_names[mask]

print(colored(
    '\nЛучшие по отзывам отели, имеющие минимум 100 отзывов:', 'green'))

display(hotels_top)

hotels['hotel_cat'] = hotels['hotel_name'].apply(
    lambda x: x if x in hotels_top.index else 'other')

# применим порядковое кодирование:
ord_encoder = OrdinalEncoder()
hotels['hotel_cat'] = hotels['hotel_cat'].astype('category')
hotels_bin = ord_encoder.fit_transform(hotels['hotel_cat'])
hotels = pd.concat([hotels, hotels_bin], axis=1)

# удалим исходный столбец
col = hotels.columns.tolist()
col[19] = 'hotel_code'

hotels.set_axis(col, axis=1, inplace=True)
hotels.drop('hotel_cat', axis=1, inplace=True);
# Out:
# Лучшие по отзывам отели, имеющие минимум 100 отзывов:
#                               mean  count
# hotel_name
# 41                           9.600    103
# Acad mie H tel Saint Germain 9.000    255
# Alma Barcelona GL            9.200    179
# Amba Hotel Charing Cross     9.300    785
# Ambassade Hotel              9.300    551
# ...                            ...    ...
# Waldorf Astoria Amsterdam    9.500    142
# art otel Amsterdam           9.000    790
# citizenM London Bankside     9.100   1517
# citizenM London Shoreditch   9.100    838
# citizenM Tower of London     9.100   1683
#
# [205 rows x 2 columns]

# %% [markdown]
# ### <span style="color:blue">АДРЕС ОТЕЛЯ ('hotel_address')</span>

# %%
addresses = pd.Series(hotels['hotel_address'].unique())

print(colored(
    '\nРассмотрим внимательно структуру строк с данными адреса:', 'green'))
display(addresses)
# Out:
# Рассмотрим внимательно структуру строк с данными адреса:
# 0                                       Via Senigallia 6 20161 Milan Italy
# 1                    Arlandaweg 10 Westpoort 1043 EW Amsterdam Netherlands
# 2                              Mallorca 251 Eixample 08008 Barcelona Spain
# 3             Piazza Della Repubblica 17 Central Station 20124 Milan Italy
# 4       Singel 303 309 Amsterdam City Center 1012 WJ Amsterdam Netherlands
#                                        ...
# 1488        45 Park Lane Westminster Borough London W1K 1PN United Kingdom
# 1489                          6 Avenue Fr miet 16th arr 75016 Paris France
# 1490                     22 avenue de Villiers 17th arr 75017 Paris France
# 1491                        17 rue de Richelieu 1st arr 75001 Paris France
# 1492                          64 Rue Crozatier 12th arr 75012 Paris France
# Length: 1493, dtype: object

# %% [markdown]
#     Из адреса можно извлечь гораздо больше полезной информации, чем из названия. Страна, город и индекс как характеристика района - могут стать дополнительными признаками!
#
#     Идентифицировать район города можно по индексу в строке адреса отеля. Район города способен сильно повлиять на впечатление туриста об отеле. Среди прочих параметров, многие туристы, оставляющие отзыв на Booking.com, часто оценивают месторасположение отеля.

# %%
# для определения гео-параметров можно воспользоваться locationtagger, 
# но он работает довольно медленно и с ошибками
# поскольку у нас небольшое количество уникальных стран и городов -
# воспользуемся простой обработкой текста:
countries = addresses.apply(lambda x: x.split()[-1])
countries = countries.apply(
    lambda x: 'United Kingdom' if x == 'Kingdom' else x)

cities = addresses.apply(lambda x: x.split()[-2])
cities = cities.apply(lambda x: 'London' if x == 'United' else x)

addresses = pd.DataFrame(
    {'address': addresses, 'country': countries, 'city': cities})

print(colored(
    '\nВ каждой стране отели представлены только из одного города:', 'green'))
display(addresses.groupby(['country', 'city']).count())

# можно добавить в данные что-то одно - я выберу страну 
#(так потом будет удобнее сопоставлять с национальностью рецензента):
hotels['hotel_country'] = hotels['hotel_address'].apply(
    lambda x: 'United Kingdom' if x.split()[-1] == 'Kingdom' else x.split()[-1])

# кодируем информацию о стране:
hotels['hotel_country'] = hotels['hotel_country'].astype('category')
hotels['hotel_country_code'] = hotels['hotel_country'].cat.codes
# Out:
# В каждой стране отели представлены только из одного города:
#                           address
# country        city
# Austria        Vienna         158
# France         Paris          458
# Italy          Milan          162
# Netherlands    Amsterdam      105
# Spain          Barcelona      211
# United Kingdom London         399

# %%
def get_postcode(address):
    """Извлечение почтового индекса из строки с адресом."""
    address_list = address.split()
    postcode_place = {
        'Kingdom': -4, 
        'Spain': -3, 
        'France': -3, 
        'Austria': -3, 
        'Netherlands': -4, 
        'Italy': -3
    }
    postcode = str(address_list[postcode_place[address_list[-1]]])
    
    if address_list[-1] == 'Kingdom' and postcode[-1].isalpha():
        return postcode[:-1]
    else:
        return postcode

    
# добавим почтовый индекс отеля как идентификатор района:
hotels['hotel_postcode'] = hotels['hotel_address'].apply(get_postcode)


"""
Замечу, что деление района на тип - центр/исторический центр/остальные -
довольно условное, строгой классификации нет и быть не может. Так как 
городов в данных совсем не много, я разметила типы районов самостоятельно,
используя информацию для туристов из открытых источников.

Просто тут я еще в самом начале работы над проектом; у меня много азарта и
энтузиазма. И я еще не знаю, что преобразования подобного рода значимо
не повлияют на итоговые метрики. А пока ...
"""

# из файла с данными о типе районов - определим категорию района:
districts = pd.read_csv('../input/projectdata/districts.csv')
districts['PostCode'] = districts['PostCode'].apply(lambda x: str(x))
districts = districts.set_index('PostCode')
districts = districts.to_dict()
districts = districts['Type of District']

hotels['district_type'] = hotels['hotel_postcode'].apply(lambda x: districts[x])

# кодируем тип района, сохраняя иерархию туристической привлекательности
# (исторический центр - самые низкие индексы, пригород - наоборот):
def get_district_code(district_type, country_code):
    """Присвоение кода району в зависимости от категории и города."""
    if district_type == 'History Center':
        return country_code
    elif district_type == 'Center':
        return country_code  + 6
    elif district_type == 'Other':
        return country_code + 12
    else:
        return country_code + 18

    
hotels['district_code'] = hotels.apply(
    lambda row: get_district_code(row['district_type'], row['hotel_country_code']
), axis=1)


# категорию району присвоим в зависимости от популярности отелей в нем у туристов
# для этого нормализуем информацию о среднем рейтинге отеля в зависимости от индекса:
pivot_adr = pd.pivot_table(
    hotels, 
    index='hotel_postcode', 
    values='average_score', 
    aggfunc='mean'
)
pivot_adr = pivot_adr.reindex(
    pivot_adr['average_score'].sort_values(ascending=False).index
)

mm_scaler = MinMaxScaler()
x_data = pivot_adr.values
x_scaled = mm_scaler.fit_transform(x_data)
pivot_adr['district_rating'] = x_scaled

hotels['district_rating'] = hotels['hotel_postcode'].apply(
    lambda x: pivot_adr['district_rating'][x]
)

hotels[['hotel_address', 
        'hotel_postcode', 
        'district_rating', 
        'district_type', 
        'hotel_country_code', 
        'district_code']][:10]
# Out:
#                                                                        hotel_address  \
# 0                                                 Via Senigallia 6 20161 Milan Italy
# 1                              Arlandaweg 10 Westpoort 1043 EW Amsterdam Netherlands
# 2                                        Mallorca 251 Eixample 08008 Barcelona Spain
# 3                       Piazza Della Repubblica 17 Central Station 20124 Milan Italy
# 4                 Singel 303 309 Amsterdam City Center 1012 WJ Amsterdam Netherlands
# 5                                 Coram Street Camden London WC1N 1HT United Kingdom
# 6                             Empire Way Wembley Brent London HA9 8DS United Kingdom
# 7                   1 Shortlands Hammersmith and Fulham London W6 8DR United Kingdom
# 8                                        35 Rue Caumartin 9th arr 75009 Paris France
# 9  49 Gloucester Place Marble Arch Westminster Borough London W1U 8JE United Kingdom
#
#   hotel_postcode  district_rating   district_type  hotel_country_code  \
# 0          20161            0.502           Other                   2
# 1           1043            0.695           Other                   3
# 2          08008            0.782          Center                   4
# 3          20124            0.697          Center                   2
# 4           1012            0.675  History Center                   3
# 5            WC1            0.502          Center                   5
# 6            HA9            0.735          Center                   5
# 7             W6            0.473           Other                   5
# 8          75009            0.678          Center                   1
# 9             W1            0.554          Center                   5
#
#    district_code
# 0             14
# 1             15
# 2             10
# 3              8
# 4              3
# 5             11
# 6             11
# 7             17
# 8              7
# 9             11

# %% [markdown]
# #### <span style="color:green">Визуализируем соотношение средних значений целевой переменной в зависимости от района расположения отеля:</span>

# %%
pivot_district_type = hotels[hotels['sample'] == 1].groupby(
    ['hotel_country', 'district_type'])['reviewer_score'].mean().unstack()

cities_rus = ['Вена', 'Париж', 'Милан', 'Амстердам', 'Барселона', 'Лондон']

fig1, ax1 = plt.subplots(figsize=(15, 6))
sns.set_style('whitegrid')
district_type_plot = pivot_district_type.plot(
    ax=ax1, 
    kind='bar', 
    width=0.85, 
    color=['indianred', 'darksalmon', 'cadetblue', 'slateblue'],
    label=cities_rus, 
    rot=0)

ax1.set_title('Зависимость средней оценки\nот расположения отеля', 
              pad = 20, size=16)
ax1.set_xlabel('')
ax1.set_xticklabels(cities_rus, fontsize=16)
ax1.legend(['Центр', 'Исторический центр', 'Остальные районы', 'Пригород'], 
           loc='upper left', fontsize=12)

# для наглядности добавим на диаграмму подписи данных:
for p in district_type_plot.patches:
    district_type_plot.annotate(
        '{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()),
    ha='center', va='bottom', fontsize=14)

plt.ylim(7, 10);

# %% [markdown]
# ### <span style="color:blue">ГЕОГРАФИЧЕСКИЕ КООРДИНАТЫ ОТЕЛЯ ('lat', 'lng')</span>

# %% [markdown]
# Вообще, координаты сами по себе мало что могут сообщить модели, но можно попробовать извлечь из них какую-то полезную информацию. Например, расстояние до центра города. Из информации о датасете мы помним, что именно в этих столбцах есть пропуски. Сначала удалим пропуски, затем добавим новый признак.

# %%
without_coor = len(hotels[hotels.isnull().any(1)]['hotel_name'].value_counts())
print(f'Количество отелей с отсутствующими координатами: {without_coor}')

# вычисляем средние значения координат для каждого района:
pivot_coor = pd.pivot_table(
    hotels, 
    index='hotel_postcode', 
    values=['lat', 'lng'], 
    dropna=True, 
    aggfunc='mean')

hotels['lat'] = hotels.apply(
    lambda row: pivot_coor['lat'][row['hotel_postcode']] \
    if np.isnan(row['lat']) else row['lat'], axis=1)
hotels['lng'] = hotels.apply(
    lambda row: pivot_coor['lng'][row['hotel_postcode']] \
    if np.isnan(row['lng']) else row['lng'], axis=1)
# Out:
# Количество отелей с отсутствующими координатами: 17

# %%
# для формирования нового признака нужны координаты центра каждого города 
# (с сайта: https://dateandtime.info/):
centers = pd.DataFrame(
    data = [
        ['United Kingdom', 'London', 51.5085300, -0.1257400],
        ['France', 'Paris', 48.8534100, 2.3488000],
        ['Spain', 'Barcelona', 41.3887900, 2.1589900],
        ['Italy', 'Milan', 45.4642700, 9.1895100],
        ['Austria', 'Vienna', 48.2084900, 16.3720800],
        ['Netherlands', 'Amsterdam', 52.3740300, 4.8896900],
    ],
    columns= ['country', 'city', 'center_lat', 'center_lng']
).set_index('country')


def get_dist_to_center(country, lng, lat):
    """Вычисление дистанции до центра города по координатам."""
    center_lat = centers['center_lat'][country]
    center_lng = centers['center_lng'][country]

    return geopy.distance.geodesic([center_lng, center_lat], [lng, lat]).km


"""
Можно вычислять координаты одной строкой кода, при помощи lambda.
Но geopy.distance.geodesic функция довольно медленная.
Чтобы не обрабатывать 500 тыс. строк - посчитаем эту характеристику 
для каждого отеля и сопоставим полученные результаты.

"""

hotels_unique = hotels[['hotel_name', 'hotel_country', 'lng', 'lat']].drop_duplicates()
hotels_unique['hotel_distance_to_center'] = hotels_unique.apply(
    lambda row: get_dist_to_center(row['hotel_country'], row['lng'], row['lat']), axis=1)

hotels_unique.drop(['hotel_country', 'lng', 'lat'], axis=1, inplace=True)
hotels = hotels.merge(hotels_unique, how='left', on='hotel_name', sort=False)

# теперь столбцы с координатами можно удалить:
hotels.drop(['lng', 'lat'], axis=1, inplace=True)

print(colored('\nПроверим новый признак:', 'green'))
hotels[['hotel_name', 'hotel_distance_to_center']][:15]
# Out:
# Проверим новый признак:
#                                     hotel_name  hotel_distance_to_center
# 0                               Hotel Da Vinci                     7.838
# 1                            Urban Lodge Hotel                     6.244
# 2   Alexandra Barcelona A DoubleTree by Hilton                     0.564
# 3                     Hotel Principe Di Savoia                     1.873
# 4                               Hotel Esther a                     0.404
# 5                Holiday Inn London Bloomsbury                     1.736
# 6                   Holiday Inn London Wembley                    18.457
# 7                          Novotel London West                    10.595
# 8                Hotel Saint Petersbourg Opera                     3.100
# 9                              St George Hotel                     3.766
# 10                                Barcel Milan                     8.903
# 11        WestCord Art Hotel Amsterdam 4 stars                     3.122
# 12               Park Plaza Victoria Amsterdam                     0.968
# 13                            Ayre Hotel Caspe                     2.406
# 14                 Best Western Atlantic Hotel                     2.565

# %% [markdown]
# ### <span style="color:blue">СРЕДНИЙ БАЛЛ ОТЕЛЯ ('average_score')</span>

# %% [markdown]
# Кажется, что это один из самых самодостаточных признаков. Это количественный параметр отеля, в той же размерности и формате, что и целевая переменная. Никаких преобразований с ним выполнять не нужно, а его влияние на показатели целевой переменной оценим в следующем блоке - анализе признаков.

# %% [markdown]
# #### <span style="color:blue">ОБЩЕЕ КОЛИЧЕСТВО ОТЗЫВОВ ОБ ОТЕЛЕ ('total_number_of_reviews')</span>
# #### <span style="color:blue">ОБЩЕЕ КОЛИЧЕСТВО ОЦЕНОК БЕЗ ОТЗЫВА ('additional_number_of_scoring')</span>

# %% [markdown]
# ## 1.2 ГРУППА ПРИЗНАКОВ ХАРКТЕРИЗУЮЩИХ РЕЦЕНЗЕНТА И ЕГО ОПЫТ ПРЕБЫВАНИЯ В ОТЕЛЕ
#
# * Страна рецензента ('reviewer_nationality')
# * Теги, которые рецензент дал отелю ('tags')
# * Количество отзывов, которые рецензенты дали в прошлом ('total_number_of_reviews_reviewer_has_given')

# %% [markdown]
# ### <span style="color:blue">СТРАНА РЕЦЕНЗЕНТА ('reviewer_nationality')</span>

# %% [markdown]
#     На самом деле, я думаю, что не столько страна, сколько социокультурные особенности представителей определенных регионов, действительно могут сказываться на оценках отелей.
#
#     Например, туристы из англо-говорящих стран, почти никогда не сталкиваются с языковым барьером в Европейских отелях. А это немаловажный фактор при заселении, выяснении дополнительной информации и решении возникающих проблем. Отсюда следует, что скорее всего такие туристы будут скорее довольны пребыванием в отеле.
#
#     А вот туристы из ближневосточных стран - могут быть недовольны европейскими отелями больше, чем остальные, так как их образ жизни сильнее отличается от европейского.
#
#     Добавим дополнительные признаки:

# %%
hotels['reviewer_nationality'] = hotels['reviewer_nationality'].apply(lambda x: x.strip())
nationality_count = len(hotels["reviewer_nationality"].value_counts())
print(f'Представители {nationality_count} стран являются рецензентами.')

# проанализируем, например, 40 самых распространенных стран, 
# из которых приезжают туристы и выделим общие группы:
print(colored('\nСамые популярные страны:', 'green'))
print(list(hotels['reviewer_nationality'].value_counts(ascending=False)[:40].index))

# выделим основные англоязычные страны:
english_list = ['United Kingdom', 
                'United States of America', 
                'Australia', 
                'Canada', 
                'New Zealand']
hotels['reviewer_en'] = hotels['reviewer_nationality'].apply(
    lambda x: 1 if x in english_list else 0)

# выделим мусульманские страны ближневосточного региона:
muslim_list = ['United Arab Emirates', 
               'Saudi Arabia', 
               'Turkey', 
               'Kuwait', 
               'Qatar', 
               'Oman']
hotels['reviewer_n_est'] = hotels['reviewer_nationality'].apply(
    lambda x: 1 if x in muslim_list else 0)

# добавим признак резидентства туриста по отношению к стране, в которой находится отель:
hotels['reviewer_resident'] = hotels.apply(
    lambda row: 1 if row['reviewer_nationality'] == row['hotel_country'] else 0, axis=1)

# кодируем информацию о стране рецензента:
hotels['reviewer_nationality'] = hotels['reviewer_nationality'].astype('category')
hotels['reviewer_nationality_cat'] = hotels['reviewer_nationality'].cat.codes
# Out:
# Представители 227 стран являются рецензентами.
#
# Самые популярные страны:
# ['United Kingdom', 'United States of America', 'Australia', 'Ireland', 'United Arab Emirates', 'Saudi Arabia', 'Netherlands', 'Switzerland', 'Germany', 'Canada', 'France', 'Israel', 'Italy', 'Belgium', 'Turkey', 'Kuwait', 'Spain', 'Romania', 'Russia', 'South Africa', 'India', 'Greece', 'China', 'Sweden', 'New Zealand', 'Singapore', 'Hong Kong', 'Poland', 'Qatar', 'Austria', 'Egypt', 'Norway', 'Czech Republic', 'Lebanon', 'Hungary', 'Malaysia', 'Thailand', 'Brazil', 'Portugal', 'Finland']

# %% [markdown]
# #### <span style="color:green">Визуализируем соотношение средних значений целевой переменной в разрезе полученных признаков:</span>

# %%
# подготовим данные для диаграммы:
mask = hotels['sample'] == 1
pivot_en = hotels[mask].groupby('reviewer_en')['reviewer_score'].mean()
pivot_n_est = hotels[mask].groupby('reviewer_n_est')['reviewer_score'].mean()
pivot_resident = hotels[mask].groupby('reviewer_resident')['reviewer_score'].mean()

pivot = pd.DataFrame({
    'из англоязычной страны': pivot_en,
    'из ближневосточной мусульманской страны': pivot_n_est,
    'путешествует по своей стране': pivot_resident 
}).T

# строим диаграмму:
fig2, ax2 = plt.subplots(figsize=(16, 6))
pivot_barplot = pivot.plot(
    ax=ax2, 
    kind='bar', 
    color=['mediumslateblue', 'seagreen'], 
    rot=0)
ax2.set_title(
    'Соотношение средних показателей оценок туристов в разрезе новых признаков', size=16)
ax2.legend(['нет', 'да'], loc='upper right', fontsize=14)

# для наглядности добавим на диаграмму подписи данных:
for p in pivot_barplot.patches:
    pivot_barplot.annotate('{:.2f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()),
    ha='center', va='bottom', fontsize=18)

plt.ylim(7, 9.5);

# %% [markdown]
# ### <span style="color:blue">ТЭГИ('tags')</span>

# %%
# сохраним в функцию способ визуализации слов, он еще пригодится:
def show_wordcloud(data, background_color, colormap):
    """Рисуем облако слов с заданными параметрами."""
    wordcloud = WordCloud(
        background_color = background_color,
        colormap = colormap,
        max_font_size = 40,
        max_words=100,
        scale = 3,
        random_state = 42
    ).generate(str(data))

    plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    plt.imshow(wordcloud)
    plt.show()

    
print('Визуализируем самые популярные теги набора данных:')

# чтобы увидеть на визуализации именно слитные Тэги, а не отдельные слова, 
# преобразуем строки данных в блоки для каждого тега:
def get_tags_string(tags_data):
    """Соединяем все слова кажого тега нижним подчеркиванием."""
    tags_data = tags_data.replace('[', '').replace(']', '').replace("'", '')
    tags_list = tags_data.split(',')

    tags_string = ''
    for teg in tags_list:
        teg = teg.strip().replace(' ', '_')
        tags_string = tags_string + teg + ' '

    return tags_string

# рисуем диаграмму:
cloud = hotels['tags'].apply(get_tags_string)
show_wordcloud(cloud, 'white', 'viridis')
# Out:
# Визуализируем самые популярные теги набора данных:

# %% [markdown]
# Рассмотрим и проанализируем типы тегов:

# %%
hotels['len_tags'] = hotels['tags'].apply(lambda x: len(x.split(',')))

print(f'Максимальное количество тегов в 1 строке данных: {hotels["len_tags"].max()}/n')

print('Примеры:')
print(hotels[hotels['len_tags'] == hotels['len_tags'].max()]['tags'].iloc[0])
print(hotels[hotels['len_tags'] == hotels['len_tags'].max()]['tags'].iloc[1])
# Out:
# Максимальное количество тегов в 1 строке данных: 6/n
# Примеры:
# [' With a pet ', ' Leisure trip ', ' Family with young children ', ' Double or Twin Room 1 2 Adults ', ' Stayed 7 nights ', ' Submitted from a mobile device ']
# [' With a pet ', ' Leisure trip ', ' Couple ', ' Deluxe Room ', ' Stayed 1 night ', ' Submitted from a mobile device ']

# %% [markdown]
# **Можно выделить 6 типов тегов:**
# * путешествие с домашними животными
# * путешествие по работе / отдых
# * путешествие в каком составе (один, пара, компания друзей, семья с маленькими / взрослыми детьми, группа)
# * категория номера
# * длительность поездки
# * доступ осуществляется с мобильного устройства

# %%
"""
Принцип выделения полезных свойств следующий - мы знаем, что максимальное 
количество тегов 6 и знаем их возможные типы. Все они, кроме типа комнаты, 
укладываются в стандартный шаблон. Будем искать в каждой строке один из пяти
известных шаблонов тега и удалать из строки после обработки. Если останется 
какой-то еще тег - он и будет типом номера.
"""

# создаем новые признаки:
def get_tags(tags_string):
    """Выделение 6 типов тегов по шаблонам."""
    tags_string = tags_string.replace('[', '').replace(']', '')
    tags_string = tags_string.replace("' ", '').replace(" '", '')
    tags_list = tags_string.split(',')
    tags_list = list(map(lambda x: x.strip(), tags_list))

    # сразу кодируем тип путешественника:
    reviewer_types = {'Solo traveler': 1,
                      'Couple': 2,
                      'Travelers with friends': 3,
                      'Family with young children': 4,
                      'Family with older children': 5,
                      'Group': 6}

    # формируем новые параметры:
    tag_from_mobile = 0
    tag_with_pet = 0
    tag_leisure_trip = 1 #  по умолчанию не считаем поездку командировкой
    tag_reviewer_type = 0
    tag_count_nights = 0
    tag_room_type = ''
    
    # распределяем те теги, которые есть в исходной строке:
    for teg in list(tags_list):
        if teg == 'Submitted from a mobile device':
            tag_from_mobile = 1
            tags_list.remove(teg)

        if teg == 'With a pet':
            tag_with_pet = 1
            tags_list.remove(teg)

        if teg == 'Business trip':
            tag_leisure_trip = 0
            tags_list.remove(teg)

        if teg == 'Leisure trip':
            tags_list.remove(teg)

        if teg in reviewer_types.keys():
            tag_reviewer_type = reviewer_types[teg]
            tags_list.remove(teg)

        if re.fullmatch(r'Stayed\s\d+\snight\w?', teg):
            tag_count_nights = [float(s) for s in re.findall(r'-?\d+\.?\d*', teg)][0]           
            tags_list.remove(teg)
            
        if len(tags_list) > 0:
            tag_room_type = tags_list[0]

    return tag_from_mobile, tag_with_pet, tag_leisure_trip, \
        tag_reviewer_type, tag_count_nights, tag_room_type


# формируем новые признаки:
hotels[['tag_from_mobile',
        'tag_with_pet',
        'tag_leisure_trip',
        'tag_reviewer_type',
        'tag_count_nights',
        'tag_room_type']
] = pd.DataFrame(hotels['tags'].apply(get_tags).to_list(), index=hotels.index)

print(colored('\nКоличество уникальных значений в новых признаках:', 'green'))
hotels[['tag_from_mobile', 'tag_with_pet', 'tag_leisure_trip', 
        'tag_reviewer_type', 'tag_count_nights', 'tag_room_type']].nunique()
# Out:
# Количество уникальных значений в новых признаках:
# tag_from_mobile         2
# tag_with_pet            2
# tag_leisure_trip        2
# tag_reviewer_type       6
# tag_count_nights       32
# tag_room_type        2394
# dtype: int64

# %% [markdown]
# Рассмотрим внимательно категории номеров. Возможно получится выделить их в группы. Кажется, что отзывы о пребывании туристов, которые останавливаются в большом клубном номере с видом и в маленьком экономе могут сильно отличаться.
#
#     Из типа номера дополнительно выделим признак - номер с видом (думаю, что средний балл отзывов гостей таких номеров должен быть выше обычных).

# %%
# оптимизируем тип данных (для последующей диаграммы):
hotels['tag_count_nights'] = hotels['tag_count_nights'].astype('int8')

# добавим признак номера с видом:
hotels['tag_view_room'] = hotels['tag_room_type'].apply(
    lambda x: 1 if ('View' in x) | ('Panoramic' in x) else 0)


# сформируем список основных категорий отельных номеров 
# и присвоим соответствующее значение каждой группе:
def get_room_type(tag):
    """Классификация типа номера."""
    room_types = ['without Window', 'Guestroom', 'Classic', 'Single', 
                  'Standard', 'Superior', 'Comfort', 'Club', 'Suite', 
                  'Deluxe', 'King', 'Premier']

    for rt in room_types:
        if rt in tag:
            return rt

    if 'Double' in tag or 'Twin' in tag:
        return 'Double'

    return 'Other'


# группируем данные с типом номера:
hotels['room_type'] = hotels['tag_room_type'].apply(get_room_type)

# кодируем новые признаки
encoder_t = OneHotEncoder(cols=['tag_reviewer_type'], use_cat_names=True)
tag_type_bin = encoder_t.fit_transform(hotels['tag_reviewer_type'])
hotels = pd.concat([hotels, tag_type_bin], axis=1)

encoder_r = OneHotEncoder(cols=['room_type'], use_cat_names=True)
tag_rooms_bin = encoder_r.fit_transform(hotels['room_type'])
hotels = pd.concat([hotels, tag_rooms_bin], axis=1)

# %% [markdown]
# #### <span style="color:green">Визуализируем таблицу распределения целевой переменной в разрезе количества проведенных в отеле дней, а также соотношение ее средних значений в зависимости от категории номера:</span>

# %%
pivot_nights = pd.pivot_table(
    hotels[hotels['sample'] == 1], 
    index='tag_count_nights', 
    values='reviewer_score', 
    aggfunc=['count', 'mean'])
fig3, ax3 = plt.subplots(figsize=(15, 7))
plt.suptitle(
    'Распределение количества отзывов в зависимости от длительности пребывания', size=20)
sns.barplot(x=pivot_nights.index, y=pivot_nights[('count', 'reviewer_score')]);

# %% [markdown]
# ***Наибольшие группы - это туристы, совершавшие короткие поездки длительностью 1-3 ночи. Логично, для городских отелей. С возрастанием длительности пребывания - количество отзывов постепенно снижается, а после показателя в 14 ночей (стандартная длина отпуска) - их количество падает резко.***
#
# Странно, что у некоторых данных отсутствует информация о длительности пребывания в отеле. Вообще сайт тщательно проверяет отзывы на реальность.
# Возможно это поездки, задним числом аннулированные отелем с возвратом денег туристу, например, а отзыв о пребывании уже был опубликован.
# Если обратить внимание на отзывы - то это в основном негативные отзывы. Не будем заменять эти значения средними показателями.

# %% [markdown]
# ***А теперь посмотрим, есть ли зависимость средних оценок от категорий номера:***

# %%
# визуализируем различия в оценках туристов, в зависимости от типа номера:
pivot_types = pd.pivot_table(hotels[hotels['sample'] == 1], 
                             index='room_type', 
                             values='reviewer_score', 
                             aggfunc=['count', 'mean'])

fig4, ax4 = plt.subplots(figsize=(15, 7))
plt.suptitle('Средняя оценка по отзывам в зависимости от категории номера', size=20)
bar_types = sns.barplot(
    x=pivot_types.index, 
    y=pivot_types[('mean', 'reviewer_score')])

for p in bar_types.patches:
    bar_types.annotate('{:.2f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()),
    ha='center', va='bottom', fontsize=20)

plt.ylim(7, 9.3);

# %% [markdown]
# Да, без окна действительно, наверно не сладко :D

# %%
# удалим вспомогательные столбцы:
hotels.drop(['tag_reviewer_type', 'room_type', 'tag_room_type', 'len_tags'], 
            axis=1, inplace=True)

# %% [markdown]
# ### <span style="color:blue">ОБЩЕЕ КОЛИЧЕСТВО ОТЗЫВОВ РЕЦЕНЗЕНТА ('total_number_of_reviews_reviewer_has_given')</span>

# %% [markdown]
# Кажется, что такой параметр, как количество отзывов у рецензента - вообще не влияет на оценку отелю. Но возможно, конечно, что "умудренные опытом" путешественники более требовательны и строги к объекту размещения. Или напротив, люди, которые много путешествуют - лучше знают чего хотят и имеют больше опыта в выборе объекта размещения. А значит, реже разочаровываются... Эти гипотезы нуждаются в проверке. Оставим решение вопроса об удалении на этап анализа и отбора признаков.

# %%
print(colored(
    '\nПосмотрим на количество отзывов рецензентов по группам активности:', 'green'))
print(hotels['total_number_of_reviews_reviewer_has_given'].groupby(
    pd.cut(hotels['total_number_of_reviews_reviewer_has_given'], 
           np.arange(0, 360, 25))).agg('count'))

# логарифмируем значение признака, чтобы оставить только информацию 
# о степени (порядке) активности рецензента:
hotels['total_number_of_reviews_reviewer_has_given'] = \
    hotels['total_number_of_reviews_reviewer_has_given'].apply(lambda x: np.log(x+1))
# Out:
# Посмотрим на количество отзывов рецензентов по группам активности:
# total_number_of_reviews_reviewer_has_given
# (0, 25]       488425
# (25, 50]       21640
# (50, 75]        3914
# (75, 100]       1149
# (100, 125]       294
# (125, 150]       144
# (150, 175]       119
# (175, 200]        21
# (200, 225]        12
# (225, 250]         8
# (250, 275]         2
# (275, 300]         4
# (300, 325]         4
# (325, 350]         1
# Name: total_number_of_reviews_reviewer_has_given, dtype: int64

# %% [markdown]
# ## 1.3 ХАРКЕТИРСТИКИ ВРЕМЕНИ - ДАТЫ И ПЕРИОДЫ
# * Дата размещения отзыва ('review_date')
# * Разница между датой отзыва и датой выгрузки данных ('days_since_review')

# %% [markdown]
# ### <span style="color:blue">ДАТА РАЗМЕЩЕНИЯ ОТЗЫВА ('review_date')</span>

# %%
# преобразуем данные в столбце в формат даты/времени:
hotels['review_date'] = pd.to_datetime(hotels['review_date'])

# формируем новые признаки:
hotels['review_week'] = hotels['review_date'].apply(
    lambda x: x.isocalendar()[1])
hotels['review_month'] = hotels['review_date'].dt.month

# %% [markdown]
# #### <span style="color:green">Визуализируем влияние месяца посещения отеля на средние настроения туристов:</span>

# %%
mask = hotels['sample'] == 1
pivot_month = hotels[mask][['review_month', 'reviewer_score']].groupby(
    'review_month').mean()
fig5, ax5 = plt.subplots(figsize=(15, 5))
plt.suptitle('Средняя оценка по отзывам в зависимости от времени года', size=16)
bar_month = sns.barplot(
    x=pivot_month.index, 
    y=pivot_month['reviewer_score'])
ax5.set_xticklabels([
    'ЯНВ', 'ФЕВ', 'МАР', 'АПР', 'MAЙ', 'ИЮН', 
    'ИЮЛ', 'АВГ', 'СЕН', 'ОКТ', 'НОЯ', 'ДЕК'])

for p in bar_month.patches:
    bar_month.annotate(
        '{:.2f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
    ha='center', va='bottom', fontsize=14)

plt.ylim(8, 8.7);

# %% [markdown]
# ### <span style="color:blue">ВОЗРАСТ ОТЗЫВА В ДНЯХ ПРИ ВЫГРУЗКЕ ДАННЫХ ('days_since_review')</span>

# %% [markdown]
# Тут даже предположить не могу - как может возраст отзыва влиять на оценку. Можно выдвинуть гипотезу, разве что, что “раньше люди были добрее”. Но так как период давности в наших данных ограничивается всего лишь 2 годами, даже она, по моему, не состоятельна :D
# Информация о возможной сезонности уже получена из даты, а этот признак удалим, со спокойной совестью, не откладывая до этапа отбора признаков.

# %%
hotels.drop('days_since_review', axis = 1, inplace=True)

# %% [markdown]
# ## 1.4 ОТЗЫВЫ
# - Отрицательный отзыв, который рецензент дал отелю ('negative_review')
# - Положительный отзыв, который рецензент дал отелю ('positive_review')
# - Общее количество слов в отрицательном отзыве ('review_total_negative_word_counts')
# - Общее количество слов в положительном отзыве ('review_total_positive_word_counts')

# %% [markdown]
# Структура отзыва об отеле на сайте “Booking.com” устроена таким образом, что содержит в себе две части: Отрицательный отзыв и Положительный отзыв.
#
# После выставления оценок по категориям рецензенту предлагается ответить на два вопроса:
# - Что вам не понравилось в объекте размещения?
# - Что вам понравилось в объекте размещения?
#
# Таким образом получается две части одного по сути отзыва.

# %% [markdown]
# ### <span style="color:blue">КОЛИЧЕСТВО СЛОВ В ОТЗЫВЕ</span>

# %% [markdown]
# Если посчитать фактическое количество слов в строке с отзывом - то оно будет отличаться от данных на 1-2 пункта.
# А количество слов равное 0 - соответствует меткам 'No Positive' / 'No Negative', то есть фактическому отсутствию отзыва.
# Не считаю этот факт критичным и оставляю данные в этом аспекте без преобразований.

# %% [markdown]
# ***Эти признаки уже напрямую дают нам информацию о том, удовлетворен ли турист пребыванием в отеле. В большинстве случаев, если все было прекрасно, на вопрос: Что вам не понравилось? - вы не ответите ничего или обойдетесь стандартной фразой типа "Все понравилось" или "Все было прекрасно!". Если же есть на что пожаловаться - эта часть отзыва будет значительно длиннее. С положительной частью - то же самое. Проверим эту гипотезу:***

# %%
fig6, ax6 = plt.subplots(figsize=(15, 7))
plt.suptitle('Взаимосвязь количества слов и поставленной оценки', size=16)
line_count_neg = sns.lineplot(
    data=hotels[mask],
    x='reviewer_score',
    y='review_total_negative_word_counts',
    color='red', linewidth=2
)
line_count_pos = sns.lineplot(
    data=hotels[mask],
    x='reviewer_score',
    y='review_total_positive_word_counts',
    color='green', linewidth=2
)
ax6.set_xlabel('')
ax6.set_ylabel('')
ax6.legend(['в негативном отзыве', '', 'в позитивном отзыве', ''], 
           loc='upper right', fontsize=12);

# %%
fig1, ax1 = plt.subplots(figsize=(15, 7))
plt.suptitle('Распределение оценок туристами по значению', size=20)
sns.histplot(
    ax=ax1, 
    data=hotels[mask]['reviewer_score'], 
    bins=len(hotels['reviewer_score'].value_counts())
).xaxis.grid(linestyle='--')
ax1.set_xticks(np.arange(0, 10.5, 0.5))
ax1.set_xlabel('');

# %%
# разделим список всех оценок с их количествами на две части
# 1) те которые укладываются в систему оценки
# 2) остальные
scores_list_1 = hotels[mask]['reviewer_score'].value_counts().iloc[:19]
scores_list_2 = hotels[mask]['reviewer_score'].value_counts().iloc[19:]

print(colored('\nОценки, укладывающиеся в систему оценивания Booking.com:', 'green'))
display(scores_list_1)

print(colored('\nОценки, не укладывающиеся в систему оценивания Booking.com:', 'green'))
display(scores_list_2)
# Out:
# Оценки, укладывающиеся в систему оценивания Booking.com:
# 10.000    86803
# 9.600     53502
# 9.200     44053
# 8.800     34795
# 8.300     30903
# 7.500     26164
# 7.900     24901
# 7.100     18529
# 6.700     14117
# 6.300     11244
# 5.800      8962
# 5.400      7082
# 5.000      6278
# 4.600      4660
# 4.200      3827
# 3.800      3017
# 3.300      2063
# 2.500      1632
# 2.900      1211
# Name: reviewer_score, dtype: int64
# Оценки, не укладывающиеся в систему оценивания Booking.com:
# 9.500    523
# 9.000    483
# 8.000    388
# 8.500    379
# 7.000    293
# 6.500    274
# 6.000    184
# 5.500    161
# 4.500     97
# 4.000     66
# 3.500     61
# 9.400     47
# 8.100     28
# 3.000     25
# 6.900     23
# 5.600     13
# 4.400      9
# 3.100      6
# Name: reviewer_score, dtype: int64

# %% [markdown]
#  Если посмотреть на динамику самых популярных оценок - то это те самые 10, 9.6, 9.2 и так далее. Вполне себе нормальное одностороннее (или экпоненциальное) распределение.
#
# А вот откуда взялись остальные оценки, с шагом по 0.5 - не очень понятно. Суммарное их количество - меньше процента от общего числа. Может это, например, результаты тестирования альтернативной системы оценивания, или просто поврежденные данные, или еще что-то.

# %%
# а теперь визуализируем связь количества слов в отзыве и уровня оценки 
# без учета этих 1% аномальных значений:
hotels_filtered = hotels[
    mask & (hotels['reviewer_score'].isin(scores_list_1.index.to_list()))]

fig7, ax7 = plt.subplots(figsize=(15, 7))
plt.suptitle(
    'Взаимосвязь количества слов в отзывах и поставленной оценки\n (игнорируем аномалии)', 
    size=16)
line_count_neg = sns.lineplot(
    data=hotels_filtered,
    x='reviewer_score',
    y='review_total_negative_word_counts',
    color='red', linewidth=2
)
line_count_pos = sns.lineplot(
    data=hotels_filtered,
    x='reviewer_score',
    y='review_total_positive_word_counts',
    color='green', linewidth=2
)
ax7.set_xlabel('')
ax7.set_ylabel('')
ax7.legend(['в негативном отзыве', '', 'в позитивном отзыве', ''], 
           loc='upper right', 
           fontsize=12);

# %% [markdown]
# #### Посмотрим на распределения этих признаков:

# %%
# формируем размеры диаграмм:
fig10, ax10 = plt.subplots(nrows=2, ncols=1, sharex='col', figsize=(15, 8))
plt.suptitle('Распределение количества слов в отзывах', size=20)

sns.boxplot(
    ax=ax10[0], 
    data=hotels['review_total_positive_word_counts'], 
    color='green', 
    width=0.4, 
    orient='h'
).grid(linestyle='--')

sns.boxplot(
    ax=ax10[1], 
    data=hotels['review_total_negative_word_counts'], 
    color='red', 
    width=0.4, 
    orient='h'
).grid(linestyle='--')
ax10[0].set_title('в положительной части:', ha='left', x=.0, fontsize=14)
ax10[1].set_title('в отрицательной части:', ha='left', x=.0, fontsize=14);

# %% [markdown]
# Целевая переменная демонстрирует зависимость от обеих величин. Соединим оба эффекта в один, добавив разницу количества слов в позитивной и негативной частях отзыва (предварительно нормализуем обе шкалы):

# %%
mm_scaler = MinMaxScaler()

hotels['review_total_positive_word_counts_norm']  = pd.DataFrame(
    mm_scaler.fit_transform(pd.DataFrame(hotels['review_total_positive_word_counts'])),
    columns=['review_total_positive_word_counts'])

hotels['review_total_negative_word_counts_norm']  = pd.DataFrame(
    mm_scaler.fit_transform(pd.DataFrame(hotels['review_total_negative_word_counts'])),
    columns=['review_total_negative_word_counts'])

# соединим эти показатели в один, отрицательные слова - с отрицательным коэффициентом:
hotels['review_total_word_counts_diff_norm'] = \
    hotels['review_total_positive_word_counts_norm'] - \
    hotels['review_total_negative_word_counts_norm']

# а также добавим флаг - преобладают ли позитивные слова над негативными 
# в размерностях соответствующих диапазонов:
hotels['positive_words_more'] = hotels['review_total_word_counts_diff_norm'].apply(
    lambda x: 1 if x >= 0 else 0)

hotels.drop(
    ['review_total_positive_word_counts_norm', 'review_total_negative_word_counts_norm'], 
    axis=1, inplace=True)

# %% [markdown]
# Также добавим долю одной из частей (второй показатель будет обратно пропорциональным, очевидно - не значимым):

# %%
hotels['review_total_word_counts'] = \
    hotels['review_total_positive_word_counts'] + \
    hotels['review_total_negative_word_counts']

# если общее количество слов равно 0, то считаем обе части равнозначными (по 0.5):
hotels['review_positive_word_proportion'] = hotels.apply(
    lambda row: 0.5 if row['review_total_word_counts'] == 0 \
            else row['review_total_positive_word_counts'] / row['review_total_word_counts'],
axis=1)

# удаляем вспомогательный столбец:
hotels.drop('review_total_word_counts', axis = 1, inplace=True)

# %% [markdown]
# ### <span style="color:blue">НЕПОСРЕДСТВЕННО ОТЗЫВ (‘negative_review’, ‘positive_review’)</span>

# %% [markdown]
# А теперь - самое интересное:D
# Огромное количество информации для лучшего предсказания итоговой оценки содержится именно в этих столбцах!
#
# Но для того чтобы параметрически оценить эти данны - нужен будет лингвистический анализ текста. Я попробую два подхода:
# *     VADER (Valence Aware Dictionary and sEntiment Reasoner) — это основанный на лексике и правилах инструмент анализа настроений, специально настроенный на чувства, выраженные в социальных сетях.
#
#     [Библиотека на GitHub тут](https://github.com/cjhutto/vaderSentiment)
#
# * TextBlob — это библиотека Python (2 и 3) для обработки текстовых данных. Он предоставляет простой API для погружения в общие задачи обработки естественного языка (NLP), такие как тегирование частей речи, извлечение именной фразы, анализ тональности, классификация, перевод и многое другое.
#
#     [Ссылка на сайт библиотеки тут ](https://textblob.readthedocs.io/en/dev/)
#
# * Собственные идеи классификации текста
#
# Начнем это увлекательнейшее исследование с красивой визуализации самых популярных слов (она стоит следующих 30 строчек кода):

# %%
# визуализируем основные слова положительных и отрицательных частей отзывов
# загружаем словарь для лемматизации
nlp = spacy.load('en_core_web_sm')
stop = stopwords.words('english')
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()


def clean_text(text):
    """Очистка от стоп-слов и лемматизация текста"""
    text = text.lower()
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    text = [word for word in text if not any(c.isdigit() for c in word)]
    text = [word for word in text if word not in stop]
    text = " ".join(text)
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


def get_words_string(words_data):
    """Соединение очищенных слов в единую строку"""
    words_string = ''
    for word in words_data:
        words_string = words_string + word + ' '
    return words_string


def draw_cloud(text_column, background, color_map):
    """Визуализация словарных наборов"""
    hotels['temp'] = hotels[text_column].apply(
        lambda x: x.replace('No Negative', '').replace('No Positive', ''))
    hotels.temp = hotels[text_column].apply(clean_text)
    cloud_data = hotels.temp.apply(get_words_string)
    # воспользуемся функцией для визуализации тегов:
    show_wordcloud(cloud_data, background, color_map)

# %%
print('\nОБЛАКО СЛОВ ПОЗИТИВНЫХ ОТЗЫВОВ:\n')
draw_cloud('positive_review', 'white', 'Dark2');
# Out:
# ОБЛАКО СЛОВ ПОЗИТИВНЫХ ОТЗЫВОВ:

# %%
print('\nОБЛАКО СЛОВ НЕГАТИВНЫХ ОТЗЫВОВ:\n')
draw_cloud('negative_review', 'white', 'BrBG');
# Out:
# ОБЛАКО СЛОВ НЕГАТИВНЫХ ОТЗЫВОВ:

# %% [markdown]
# ### Анализ настроений с помощью SentimentIntensityAnalyzer библиотеки VADER:

# %% [markdown]
#   SentimentIntensityAnalyzer от VADER выводит оценку на 3 уровнях классификации, а также составную оценку. В результате мы получим словарь нормализованных оценок тональности текста по категориям:
# - негативная оценка
# - нейтральная оценка
# - позитивная
#
#   Из документации VADER по составной оценке: составная оценка вычисляется путем суммирования оценок валентности каждого слова в лексиконе, корректируется в соответствии с правилами, а затем нормализуется так, чтобы быть в диапазоне от -1 (крайнее отрицательное значение) до +1 (крайнее положительное значение).
#
# И все бы хорошо, но одни и те же слова в положительном и отрицательном контекстах будут иметь противоположную тональность.
#
# ### “Все” или “Ничего”?
#
# Вспомним, что положительный и отрицательные части отзыва - это ответы на два вопроса сайта о том что понравилось / не понравилось в отеле. А структура английского языка такова (как выяснилось), что ответ на вопрос “Что вам не понравилось?”: “Ничего” (nothing) - будет означать, что ничего не не понравилось, то есть - все понравилось. Самый положительный контекст. Но тоже самое “Ничего” в ответ на вопрос: “Что вам понравилось?” будет означать ровно обратное.
#
# А вот слово “все” (everything) такой семантики не имеет (вроде бы).
#
# Эти слова изначально для анализатора имеют нейтральную тональность, но в качестве ответа на вопрос, хорошо было бы эту тональность именно таких самых популярных слов изменить. Причем разным образом для разных частей отзывов.
#
# Надо понимать, что конечно, эти слова могут встречаться те только в коротких ответах, но и в развернутых предложениях, где они такого смысла иметь не будут. Но и не будут иметь большого веса в общей оценке. Мы можем этими ситуациями принебречь.
#
# Так же слово “small” мы встретим в огромной части отрицательных отзывов - Small room, Small bed, Small pool. И невинно нейтральное small в отрицательных отзывах об отелях принимает негативный контекст.
#
# Для работы с разными частями отзывов я создам два разных анализатора - SentimentIntensityAnalyzer, а лексикон каждого настрою для соответствующей части отзывов.
#
#   И еще один момент. Вообще, метками ‘No Negative’ / ‘No Positive’ обозначается отсутствие отзыва. Если оставить все как есть, то анализатор отбросив “No”, выдаст тональность противоположного по значению слова. Можно вообще удалить эти значения, заменив на пустую строку, но для нас отсутствие отрицательно отзыва - означает - отсутствие отрицательного опыта пребывания и наоборот, по этому оставим эти фразы для анализа, предварительно переформулировав фразы без “не”. А вот если не написано вообще ничего, то взаимные разнонаправленные тональности обеих меток в сумме дадут нейтральный 0.

# %%
# создаем два экземпляра анализатора, чтобы разделить лексикон 
# для разной системы оценки положительных и отрицательных отзывов:
sia_pos = SentimentIntensityAnalyzer()
sia_neg = SentimentIntensityAnalyzer()

# посмотрим как изменится характеристика слова 'nothing':
example = 'nothing'
print(f'Словарь оценок слова "{example}" до преобразований:')
print(sia_neg.polarity_scores(example), '\n')

# добавим контекст:
neg_words = {'small': -1, 'nothing': 10}
pos_words = {'nothing': -10, 'everything': 10}
sia_neg.lexicon.update(neg_words)
sia_pos.lexicon.update(pos_words)

print(f' - после преобразований (для негативного контекста):')
print(sia_neg.polarity_scores(example))
print(f' - после преобразований (для позитивного контекста):')
print(sia_pos.polarity_scores(example))

# фразы "No Negative" тонально будет нести негативную окраску:
example = 'No Negative'
print(f'\nСловарь оценок фразы "{example}":')
print(sia_neg.polarity_scores(example))
example = 'Positive'
print(f'Словарь оценок фразы "{example}":')
print(sia_neg.polarity_scores(example))

# меняем метки отсутствия частей отзыва:
hotels['negative_review_temp'] = hotels['negative_review'].apply(
    lambda x: x.replace('No Negative', 'Positive'))
hotels['positive_review_temp'] = hotels['positive_review'].apply(
    lambda x: x.replace('No Positive', 'Negative'))
# Out:
# Словарь оценок слова "nothing" до преобразований:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#  - после преобразований (для негативного контекста):
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.9325}
#  - после преобразований (для позитивного контекста):
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.9325}
#
# Словарь оценок фразы "No Negative":
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.7096}
# Словарь оценок фразы "Positive":
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5574}

# %%
# %%time
# понеслась?)
hotels['negative_review_sentiments'] = hotels['negative_review_temp'].apply(
    lambda x: sia_neg.polarity_scores(x))
hotels['positive_review_sentiments'] = hotels['positive_review_temp'].apply(
    lambda x: sia_pos.polarity_scores(x))

# формируем новые признаки:
hotels['n_review_sentiments_neg'] = hotels['negative_review_sentiments'].apply(
    lambda x: x['neg'])
hotels['n_review_sentiments_neu'] = hotels['negative_review_sentiments'].apply(
    lambda x: x['neu'])
hotels['n_review_sentiments_pos'] = hotels['negative_review_sentiments'].apply(
    lambda x: x['pos'])
hotels['n_review_sentiments_compound'] = hotels['negative_review_sentiments'].apply(
    lambda x: x['compound'])

hotels['p_review_sentiments_neg'] = hotels['positive_review_sentiments'].apply(
    lambda x: x['neg'])
hotels['p_review_sentiments_neu'] = hotels['positive_review_sentiments'].apply(
    lambda x: x['neu'])
hotels['p_review_sentiments_pos'] = hotels['positive_review_sentiments'].apply(
    lambda x: x['pos'])
hotels['p_review_sentiments_compound'] = hotels['positive_review_sentiments'].apply(
    lambda x: x['compound'])
# кстати, не очень долго считает (толи еще будет!)
# Out:
# CPU times: user 3min 54s, sys: 2.5 s, total: 3min 56s
# Wall time: 3min 56s

# %% [markdown]
# ### Анализ настроений с помощью TextBlob:

# %% [markdown]
# TextBlob работает немного по другому. В отличие от Vader, он анализирует не слова, а фразы и предложения, выдавая такие параметры как: полярность и субъективность.
#
# Полярность — это число с плавающей запятой от -1 до 1, где -1 — отрицательное утверждение, а 1 — положительное утверждение.
# Субъективность — это показатель TextBlob, определяющий, считается ли утверждение в большей степени личным мнением или оно основано на фактах.
#
# Для оценки настроения рецензента будем использовать параметр полярности.
#
# Также при помощи NaiveBayesAnalyzer можно получить классификацию настроений (аналогичную Vader) в негативной и позитивной частях отзыва и, на основе этих данных выведем категорию отзыва, руководствуясь следующей логикой:
#
# ***- (восторженный) обе части имеют позитивную тональность: высшая категория***
# туристу так все понравилось, что и в ответе на вопрос о недостатках - он выражает положительные эмоции
#
# ***- (конструктивный) позитивная часть имеют позитивную тональность, негативная часть - негативную: средняя высокая категория***
# объективный поиск достоинств и недостатков отеля
#
# ***- (снисходительный) позитивная часть имеет негативную тональность, негативная - позитивную: средняя низкая категория***
# пребывание скорее не понравилось, но отзыв о недостатках не жесткий
#
# ***- (разочарованный) обе части имеют негативную тональность: низшая категория***
# ничего не понравилось
#
# Исходя из шкалы оценивания отеля - выберем 4 оценки в диапазоне от 2.5 до 10 с равным шагом.

# %%
# так как этот анализатор работает не со словами, а с фразами, 
# то он справляется с выражениями 'No Negative' / 'No Positive':
text_example = 'No Negative'
example = TextBlob(text_example)
print(f'Полярность фразы "{text_example}": \
{round(example.sentiment_assessments.polarity,2)}')

text_example = 'No Positive'
example = TextBlob(text_example)
print(f'Полярность фразы "{text_example}": \
{round(example.sentiment_assessments.polarity,2)}')
# Out:
# Полярность фразы "No Negative": 0.15
# Полярность фразы "No Positive": -0.11

# %%
# %%time

def get_polarity(text):
    """Получение параметра полярности отзыва"""
    blob = TextBlob(text)
    return blob.sentiment_assessments.polarity

hotels['positive_polarity'] = hotels['positive_review_temp'].apply(get_polarity)
hotels['negative_polarity'] = hotels['negative_review_temp'].apply(get_polarity)
# Out:
# CPU times: user 5min 35s, sys: 298 ms, total: 5min 35s
# Wall time: 5min 35s

# %% [markdown]
# Так же в библиотеке есть способ получить коэффициенты негативной и позитивной окраски (в сумме дают 1) и классифицировать текст в зависимости от того, какой компонент преобладает.

# %%
# %%time

tb = Blobber(analyzer=NaiveBayesAnalyzer())

text_example = 'everything was great'
print(f'{tb(text_example).sentiment} для фразы "{text_example}"')

# так как позитивный и негативный компонент - взаимнообратные величины, образующие в сумме 1 - 
# можно ограничится только одним:
def get_blobber_sentiment(text):
    """Получение коэффициента позитивной оценки"""
    blobber_sentiment = tb(text).sentiment
    return blobber_sentiment[1]

hotels['positive_review_pos'] = hotels['positive_review_temp'].apply(get_blobber_sentiment)
hotels['negative_review_pos'] = hotels['negative_review_temp'].apply(get_blobber_sentiment)
# Out:
# Sentiment(classification='pos', p_pos=0.6252594845412645, p_neg=0.37474051545873566) для фразы "everything was great"
# CPU times: user 5min 13s, sys: 674 ms, total: 5min 13s
# Wall time: 5min 15s

# %%
# добавим отзыву классификацию в зависимости от доли положительного компонента:
hotels['positive_review_class'] = hotels['positive_review_pos'].apply(
    lambda x: 1 if x >= 0.5 else 0)
hotels['negative_review_class'] = hotels['negative_review_pos'].apply(
    lambda x: 1 if x >= 0.5 else 0)


# добавляем параметр с классификацией отзыва:
def get_class(positive_review_class, negative_review_class):
    """Классификация отзыва, в зависимости от классов обеих частей"""
    if positive_review_class + negative_review_class == 2:
        return 10.0 # 10.0
    if positive_review_class == 1 and negative_review_class == 0:
        return 7.5 #7.5
    if positive_review_class == 0 and negative_review_class == 1:
        return 5.0  #5.0
    return 2.5  #2.5


hotels['review_classification'] = hotels.apply(
    lambda row: get_class(row['positive_review_class'], row['negative_review_class']), 
    axis=1)

# %% [markdown]
# ### Собственные эксперименты:

# %% [markdown]
# Предыдущими методами мы получили несколько классификаций, основанных на анализе настроений, но не учитывающих специфический лексикон рецензентов, пишущих именно об отелях. На самом деле, есть куча конструктивных отзывов, описывающих достоинства обстоятельно, но без сильных эмоций. И хочется понять, что рецензент рассуждает об отеле в ключе самых хвалебных отзывов.
#
# Я попробовала найти простой способ сравнить все отзывы с лучшими и выявить какой-то коэффициент похожести. Но как понять, какие - лучшие?
#
# Я попробую создать некий набор слов типичных для положительных отзывов, основываясь на положительной части отзывов о лучших отелях (с самым высоким среднем рейтингом). Потом оценим, какой процент слов каждого отзыва пересекается с этим набором.
#
# (Кстати с отрицательными отзывами - этот подход не сработал, так как люди пишут отрицательные отзывы часто более обстоятельно, даже если не сильно снижают оценку.)

# %%
# %%time

# формируем единый блок текста обеих частей отзыва и избавляемся от меток отсутствия слов:
hotels['negative_review_temp'] = hotels['negative_review'].apply(
    lambda x: x.replace('No Negative', ''))
hotels['positive_review_temp'] = hotels['positive_review'].apply(
    lambda x: x.replace('No Positive', ''))
hotels['review'] = hotels['positive_review_temp'] + ' ' + hotels['negative_review_temp']


# функция преобразования строки в набор слов:
def get_words_set(text):
    """Формирование наборов уникальных слов текста"""
    text = text.lower()
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    text = [word for word in text if not any(c.isdigit() for c in word)]
    text = [word for word in text if len(word) > 2]
    text = [word for word in text if word not in stop]
    text = " ".join(text)
    words_data = [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]
    words_set = set()
    for word in words_data:
        words_set.add(word)
    return words_set


# формируем наборы уникальных слов каждого отзыва:
hotels['review_word_set'] = hotels['review'].apply(get_words_set)

# зато быстро!
# Out:
# CPU times: user 1min 45s, sys: 2.74 s, total: 1min 48s
# Wall time: 1min 48s

# %%
best_words_set = set()

# подберем образцы текста отзывов о лучших отелях:
hotels_top = pd.DataFrame(hotels[hotels['average_score'] >= 9.6])
hotels_top['positive_review_word_set'] = hotels_top['positive_review'].apply(get_words_set)
hotels_top_list = hotels_top['positive_review_word_set'].tolist()

for review_set in hotels_top_list:
    best_words_set.update(review_set)

best_hotels_count = len(hotels[hotels['average_score'] >= 9.6]['hotel_name'].value_counts())

print(f'Количество уникальных слов, отобранное по результатам {len(hotels_top_list)} отзывов '
      f'{best_hotels_count} лучших отелей: {len(best_words_set)}.')
# Out:
# Количество уникальных слов, отобранное по результатам 943 отзывов 7 лучших отелей: 2044.

# %%
def get_diff_with_top(review_words_set):
    """Определение доли слов отзыва, встречающихся также в отзывах о топ-отелях"""
    set_len = len(review_words_set)
    if set_len == 0:
        return 0
    top_words_count = 0
    for word in review_words_set:
        if word in best_words_set :
            top_words_count += 1

    return round(top_words_count / set_len, 2)


# формируем новый признак:
hotels['review_difference_with_top'] = hotels['review_word_set'].apply(get_diff_with_top)

# %% [markdown]
# ### Бонус! Короткий код с Afinn:

# %% [markdown]
# На самом деле, решений задач сентимент-анализа - огромное множество, куча библиотек и разных анализаторов. Те, которые использовала я - наверно самые популярные и довольно понятные новичку.
#
# Однако, блуждая по бескрайним просторам интернета, я наткнулась еще на один лаконичный и простой способ получить коэффициент настроения текста. Afinn — это подход к анализу настроений на основе списка слов. Он не нормализует оценки и мы получаем коэффициент, соотносимый с масштабом количества слов отзыва. То есть, своего рода взвешенную по количеству слов оценку:

# %%
# %%time

afinn = Afinn()
hotels['afinn_score'] = hotels['review'].apply(lambda x: afinn.score(x))
# Out:
# CPU times: user 5min 36s, sys: 195 ms, total: 5min 37s
# Wall time: 5min 37s

# %% [markdown]
# #### <span style="color:green">Визуализируем соотношение оценок туристами и коэффициентов afinn:</span>

# %%
# тепловая карта под конец раздела:
hotels_filtered = hotels[mask & (hotels['reviewer_score'].isin(
    scores_list_1.index.to_list()))]
pivot = hotels_filtered.pivot_table(
    values='review', 
    index='reviewer_score', 
    columns='afinn_score', 
    aggfunc='count')

# строим диаграмму:
fig8, ax8 = plt.subplots(1, 1, figsize = (15, 6))
afinn_heatmap = sns.heatmap(data=pivot, cmap='YlGnBu')
ax8.invert_yaxis();

# %%
# ограничим размеры диапазона значений по методу Тьюки:
def get_outliers_bonds(data, feature):
    """Определяем границы диапазонов для ограничения значений"""
    x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower = quartile_1 - (iqr * 1.5)
    upper = quartile_3 + (iqr * 1.5)
    return lower, upper


lower_bound, upper_bound = get_outliers_bonds(hotels, 'afinn_score')

hotels['afinn_score'] = hotels['afinn_score'].apply(
    lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %% [markdown]
# # 2. Анализ и отбор признаков (FEATURE SELECTION):

# %%
# создаем дубликат базы для дальнейших манипуляций со столбцами (для обратимости экспериментов):
hotels_copy = hotels.copy()

# %%
hotels_copy = hotels_copy.drop(['review'], axis = 1)

# %%
print(f'Текущее получившееся количество признаков: {len(hotels_copy.columns)}')
print('(включая целевой столбец и метку тест/трейн)')

# удалим нечисловые данные:
object_columns = [s for s in hotels_copy.columns
                  if ((hotels_copy[s].dtypes == 'object') | \
                      (hotels_copy[s].dtype.name == 'category') | \
                      (hotels_copy[s].dtypes == 'datetime64[ns]'))]

print(f'Удалим {len(object_columns)} столбцов с нечисловыми данными')
hotels_copy = hotels_copy.drop(object_columns, axis = 1)
# Out:
# Текущее получившееся количество признаков: 80
# (включая целевой столбец и метку тест/трейн)
# Удалим 16 столбцов с нечисловыми данными

# %% [markdown]
# ### Разделим числовые признаки на группы:

# %%
# непрерывные и категориальные признаки:
num_cols = [
    # признаки связанные с количеством слов:
    'review_total_negative_word_counts', 'review_total_positive_word_counts',
    'review_total_word_counts_diff_norm', 'review_positive_word_proportion',

    # признаки, связанные с анализом эмоциональной окраски отзывов:
    'n_review_sentiments_neg', 'n_review_sentiments_neu',
    'n_review_sentiments_pos', 'n_review_sentiments_compound',
    'p_review_sentiments_neg', 'p_review_sentiments_neu',
    'p_review_sentiments_pos', 'p_review_sentiments_compound',
    'negative_polarity', 'positive_polarity', 
    'negative_review_pos', 'positive_review_pos', 
    'review_difference_with_top', 'afinn_score',
    
    # остальные количественные:
    'total_number_of_reviews_reviewer_has_given', 'tag_count_nights'
]

cat_cols = [
    # характеристики отеля
    'average_score', 'additional_number_of_scoring', 'total_number_of_reviews',
    'hotel_code', 'hotel_country_code', 'district_code', 
    'district_rating', 'hotel_distance_to_center',

    # характеристики поездки (номер):
    'tag_leisure_trip', 'tag_view_room', 'room_type_without Window', 
    'room_type_Suite', 'room_type_Standard', 'room_type_Double',
    'room_type_Superior', 'room_type_Club', 'room_type_Comfort', 
    'room_type_Deluxe', 'room_type_Premier', 'room_type_Classic', 
    'room_type_King', 'room_type_Single', 'room_type_Guestroom', 'room_type_Other',

    # характеристики рецензента:
    'reviewer_en', 'reviewer_n_est', 'reviewer_resident', 
    'reviewer_nationality_cat', 'tag_from_mobile', 'tag_with_pet',
    'tag_reviewer_type_1.0', 'tag_reviewer_type_2.0', 'tag_reviewer_type_3.0',
    'tag_reviewer_type_4.0', 'tag_reviewer_type_5.0', 'tag_reviewer_type_6.0',

    # время поездки:
    'review_week', 'review_month',

    # характеристики отзыва:
    'review_classification', 'positive_words_more', 
    'negative_review_class', 'positive_review_class',
]

# %% [markdown]
# ## 2.1 АНАЛИЗ МУЛЬТИКОЛЛИНЕАРНОСТИ
#
#
# Поскольку признаков очень много оценим коллинеарность по смысловым группам:

# %% [markdown]
# ### АНАЛИЗ МУЛЬТИКОЛЛИНЕАРНОСТИ НЕПРЕРЫВНЫХ ПРИЗНАКОВ

# %%
def show_corr_heatmap(columns_list, title, method):
    """Построения корреляционной диаграммы"""
    fig_, ax_ = plt.subplots(figsize=(15, 12))
    corr = hotels_copy[columns_list].corr(method=method)
    mask = np.triu(np.ones_like(corr, dtype=bool))
    sns.heatmap(corr, 
                annot=True, 
                linewidths=0.1, 
                ax=ax_, 
                mask=mask, 
                cmap='viridis',
                fmt='.1g')
    ax_.set_title(title, fontsize=18)
    plt.show()

# %%
#строим диаграмму для непрерывных признаков:
show_corr_heatmap(num_cols, 'КОРРЕЛЯЦИЯ НЕПРЕРЫВНЫХ ПРИЗНАКОВ', method='pearson');

# %% [markdown]
# Отбираем на удаление два признака из пар имеющих модуль корреляции больше 0.8.

# %%
# внесем столбцы в список на удаление:
drop_columns = ['n_review_sentiments_neu']

# %% [markdown]
# ### АНАЛИЗ МУЛЬТИКОЛЛИНЕАРНОСТИ КАТЕГОРИАЛЬНЫХ ПРИЗНАКОВ
#
# Разделим категориальные признаки на 2 смысловые группы:

# %%
# в первый блок отнесем характеристики отеля и номера:
cat_cols_p1 = cat_cols[:24]

# во второй блок - характеристики рецензента, времени поездки и отзыва:
cat_cols_p2 = cat_cols[24:]

# %%
# строим диаграмму для первой части категориальных признаков:
show_corr_heatmap(
    cat_cols_p1, 
    'КОРРЕЛЯЦИЯ КАТЕГОРИАЛЬНЫХ ПРИЗНАКОВ\n(параметры отеля и категории номера)', 
    method='spearman'
);

# %%
# внесем столбцы в список на удаление:
drop_columns += ['additional_number_of_scoring']

# %%
# строим диаграмму для первой части категориальных признаков:
show_corr_heatmap(
    cat_cols_p2, 
    'КОРРЕЛЯЦИЯ КАТЕГОРИАЛЬНЫХ ПРИЗНАКОВ\n(параметры рецензента, отзыва и времени поездки)', 
    method='spearman'
);

# %% [markdown]
# А из этого списка можно удалить признак недели или месяца (удалим месяц) и классификацию отзыва (он сильно коррелирует с признаками из которых выведен).

# %%
# внесем столбцы в список на удаление:
drop_columns += ['review_month', 'review_classification']

# %%
# удалим выбранные столбцы:
hotels_copy.drop(drop_columns, axis = 1, inplace=True)

print(f'Текущее получившееся количество признаков: {len(hotels_copy.columns)}')
print('(включая столбец "Sample" и целевой столбец)')
# Out:
# Текущее получившееся количество признаков: 60
# (включая столбец "Sample" и целевой столбец)

# %%
hotels_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515738 entries, 0 to 515737
# Data columns (total 60 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   average_score                               515738 non-null  float64
#  1   review_total_negative_word_counts           515738 non-null  int64
#  2   total_number_of_reviews                     515738 non-null  int64
#  3   review_total_positive_word_counts           515738 non-null  int64
#  4   total_number_of_reviews_reviewer_has_given  515738 non-null  float64
#  5   sample                                      515738 non-null  int64
#  6   reviewer_score                              515738 non-null  float64
#  7   hotel_code                                  515738 non-null  int64
#  8   hotel_country_code                          515738 non-null  int8
#  9   district_code                               515738 non-null  int64
#  10  district_rating                             515738 non-null  float64
#  11  hotel_distance_to_center                    515738 non-null  float64
#  12  reviewer_en                                 515738 non-null  int64
#  13  reviewer_n_est                              515738 non-null  int64
#  14  reviewer_resident                           515738 non-null  int64
#  15  reviewer_nationality_cat                    515738 non-null  int16
#  16  tag_from_mobile                             515738 non-null  int64
#  17  tag_with_pet                                515738 non-null  int64
#  18  tag_leisure_trip                            515738 non-null  int64
#  19  tag_count_nights                            515738 non-null  int8
#  20  tag_view_room                               515738 non-null  int64
#  21  tag_reviewer_type_2.0                       515738 non-null  int64
#  22  tag_reviewer_type_6.0                       515738 non-null  int64
#  23  tag_reviewer_type_1.0                       515738 non-null  int64
#  24  tag_reviewer_type_4.0                       515738 non-null  int64
#  25  tag_reviewer_type_5.0                       515738 non-null  int64
#  26  tag_reviewer_type_3.0                       515738 non-null  int64
#  27  room_type_Double                            515738 non-null  int64
#  28  room_type_Other                             515738 non-null  int64
#  29  room_type_Suite                             515738 non-null  int64
#  30  room_type_Classic                           515738 non-null  int64
#  31  room_type_Standard                          515738 non-null  int64
#  32  room_type_Superior                          515738 non-null  int64
#  33  room_type_Single                            515738 non-null  int64
#  34  room_type_King                              515738 non-null  int64
#  35  room_type_Deluxe                            515738 non-null  int64
#  36  room_type_Club                              515738 non-null  int64
#  37  room_type_without Window                    515738 non-null  int64
#  38  room_type_Premier                           515738 non-null  int64
#  39  room_type_Comfort                           515738 non-null  int64
#  40  room_type_Guestroom                         515738 non-null  int64
#  41  review_week                                 515738 non-null  int64
#  42  review_total_word_counts_diff_norm          515738 non-null  float64
#  43  positive_words_more                         515738 non-null  int64
#  44  review_positive_word_proportion             515738 non-null  float64
#  45  n_review_sentiments_neg                     515738 non-null  float64
#  46  n_review_sentiments_pos                     515738 non-null  float64
#  47  n_review_sentiments_compound                515738 non-null  float64
#  48  p_review_sentiments_neg                     515738 non-null  float64
#  49  p_review_sentiments_neu                     515738 non-null  float64
#  50  p_review_sentiments_pos                     515738 non-null  float64
#  51  p_review_sentiments_compound                515738 non-null  float64
#  52  positive_polarity                           515738 non-null  float64
#  53  negative_polarity                           515738 non-null  float64
#  54  positive_review_pos                         515738 non-null  float64
#  55  negative_review_pos                         515738 non-null  float64
#  56  positive_review_class                       515738 non-null  int64
#  57  negative_review_class                       515738 non-null  int64
#  58  review_difference_with_top                  515738 non-null  float64
#  59  afinn_score                                 515738 non-null  float64
# dtypes: float64(20), int16(1), int64(37), int8(2)
# memory usage: 246.3 MB

# %% [markdown]
# ## 2.2 ОЦЕНКА ЗНАЧИМОСТИ ПРИЗНАКОВ

# %% [markdown]
# Проведем оценку значимости признаков. Я бы отнесла наш целевой признак к категории - количественный дискретный. Воспользуемся для оценки дисперсионным анализом ANOVA. Теперь делить признаки на группы не корректно, нам нужно получить абсолютно худшие во всей совокупности:

# %%
y = hotels_copy.query('sample == 1').drop(['sample'], axis=1).reviewer_score.values
X = hotels_copy.query('sample == 1').drop(['sample', 'reviewer_score'], axis=1)

# визуализируем результат анализа значимости:
imp_num = pd.Series(f_classif(X[X.columns], y)[0], index = X.columns)
imp_num.sort_values(inplace = True)

fig5, ax5 = plt.subplots(figsize=(15, 20))
imp_num.plot(kind = 'barh', color='green');

# %% [markdown]
# Удалим признаки, не демонстрирующие никакой корреляции с целевым. Это признаки некоторых типов номеров и типов путешественника, а также признак путешественников с животными.
#
# Хотя у меня была гипотеза, что может быть их оценки в целом выше, так как не многие отели пускают постояльцев с домашними питомцами, и возможно, благодарные хозяева оставляют позитивные отзывы. Но нет...)

# %%
drop_columns = ['room_type_Other', 'room_type_Club', 'room_type_Comfort', 
                'room_type_Double', 'room_type_Premier', 'tag_with_pet',
                'tag_reviewer_type_3.0', 'tag_reviewer_type_4.0', 
                'tag_reviewer_type_5.0', 'tag_reviewer_type_6.0']

# %%
# удалим незначимые числовые данные:
print(f'Удалим еще {len(drop_columns)} столбцов с числовыми данными')
hotels_copy.drop(drop_columns, axis = 1, inplace=True)

print(f'Итоговое получившееся количество признаков: {len(hotels_copy.columns)}')
print('(включая столбец "Sample" и целевой столбец)')
# Out:
# Удалим еще 10 столбцов с числовыми данными
# Итоговое получившееся количество признаков: 50
# (включая столбец "Sample" и целевой столбец)

# %%
hotels_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515738 entries, 0 to 515737
# Data columns (total 50 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   average_score                               515738 non-null  float64
#  1   review_total_negative_word_counts           515738 non-null  int64
#  2   total_number_of_reviews                     515738 non-null  int64
#  3   review_total_positive_word_counts           515738 non-null  int64
#  4   total_number_of_reviews_reviewer_has_given  515738 non-null  float64
#  5   sample                                      515738 non-null  int64
#  6   reviewer_score                              515738 non-null  float64
#  7   hotel_code                                  515738 non-null  int64
#  8   hotel_country_code                          515738 non-null  int8
#  9   district_code                               515738 non-null  int64
#  10  district_rating                             515738 non-null  float64
#  11  hotel_distance_to_center                    515738 non-null  float64
#  12  reviewer_en                                 515738 non-null  int64
#  13  reviewer_n_est                              515738 non-null  int64
#  14  reviewer_resident                           515738 non-null  int64
#  15  reviewer_nationality_cat                    515738 non-null  int16
#  16  tag_from_mobile                             515738 non-null  int64
#  17  tag_leisure_trip                            515738 non-null  int64
#  18  tag_count_nights                            515738 non-null  int8
#  19  tag_view_room                               515738 non-null  int64
#  20  tag_reviewer_type_2.0                       515738 non-null  int64
#  21  tag_reviewer_type_1.0                       515738 non-null  int64
#  22  room_type_Suite                             515738 non-null  int64
#  23  room_type_Classic                           515738 non-null  int64
#  24  room_type_Standard                          515738 non-null  int64
#  25  room_type_Superior                          515738 non-null  int64
#  26  room_type_Single                            515738 non-null  int64
#  27  room_type_King                              515738 non-null  int64
#  28  room_type_Deluxe                            515738 non-null  int64
#  29  room_type_without Window                    515738 non-null  int64
#  30  room_type_Guestroom                         515738 non-null  int64
#  31  review_week                                 515738 non-null  int64
#  32  review_total_word_counts_diff_norm          515738 non-null  float64
#  33  positive_words_more                         515738 non-null  int64
#  34  review_positive_word_proportion             515738 non-null  float64
#  35  n_review_sentiments_neg                     515738 non-null  float64
#  36  n_review_sentiments_pos                     515738 non-null  float64
#  37  n_review_sentiments_compound                515738 non-null  float64
#  38  p_review_sentiments_neg                     515738 non-null  float64
#  39  p_review_sentiments_neu                     515738 non-null  float64
#  40  p_review_sentiments_pos                     515738 non-null  float64
#  41  p_review_sentiments_compound                515738 non-null  float64
#  42  positive_polarity                           515738 non-null  float64
#  43  negative_polarity                           515738 non-null  float64
#  44  positive_review_pos                         515738 non-null  float64
#  45  negative_review_pos                         515738 non-null  float64
#  46  positive_review_class                       515738 non-null  int64
#  47  negative_review_class                       515738 non-null  int64
#  48  review_difference_with_top                  515738 non-null  float64
#  49  afinn_score                                 515738 non-null  float64
# dtypes: float64(20), int16(1), int64(27), int8(2)
# memory usage: 207.0 MB

# %%
end_time = dt.now(tz).strftime("%H:%M:%S")
end_time = dt.strptime(end_time, "%H:%M:%S")
result_time = end_time - start_time
print(f'На подготовку данных ушло: {result_time}')
# Out:
# На подготовку данных ушло: 0:29:00

# %% [markdown]
# # 3. Обучение модели и получение предсказания (Model Building):

# %% [markdown]
# ### Разбиваем датафрейм на части, необходимые для обучения и тестирования модели:

# %%
# теперь выделим тестовую часть
train_data = hotels_copy.query('sample == 1').drop(['sample'], axis=1)
test_data = hotels_copy.query('sample == 0').drop(['sample'], axis=1)

y = train_data.reviewer_score.values
X = train_data
X.shape, y.shape
# Out:
# ((386803, 49), (386803,))

# %%
X_data, y_data = train_test_split(train_data, test_size=TEST_SIZE, random_state=RANDOM_STATE)
print(f'Data splitted. Parts sizes: \nX_data = {X_data.shape} \ny_data = {y_data.shape}')
# Out:
# Data splitted. Parts sizes:
# X_data = (309442, 49)
# y_data = (77361, 49)

# %%
task = Task('reg', loss = 'mape')
roles = {'target': TARGET_NAME}

# %%
# %%time
# Задаем параметры модели
automl = TabularAutoML(
    task = task, 
    timeout = 3600,
    cpu_limit = 4,
    reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE}
)

# Обучаем модель
oof_pred = automl.fit_predict(X_data, roles = roles, verbose = 4)
# Out:
# [07:01:26] Stdout logging level is DEBUG.
# [07:01:26] Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# [07:01:26] Task: reg
#
# [07:01:26] Start automl preset with listed constraints:
# [07:01:26] - time: 3600.00 seconds
# [07:01:26] - CPU: 4 cores
# [07:01:26] - memory: 16 GB
#
# [07:01:26] Train data shape: (309442, 49)
#
# [07:01:34] Feats was rejected during automatic roles guess: []
# [07:01:34] Layer 1 train process start. Time left 3591.89 secs
# [07:01:54] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [07:01:54] Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [63], 'embed_sizes': array([9], dtype=int32), 'data_size': 64}
# [07:01:54] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [07:01:55] Linear model: C = 1e-05 score = -1.4551152222410615
# [07:01:56] Linear model: C = 5e-05 score = -1.4144028589861932
# [07:01:56] Linear model: C = 0.0001 score = -1.4083616016441327
# [07:01:57] Linear model: C = 0.0005 score = -1.39794801797924
# [07:01:57] Linear model: C = 0.001 score = -1.3973826651336025
# [07:01:58] Linear model: C = 0.005 score = -1.3976973126851056
# [07:01:58] Linear model: C = 0.01 score = -1.3976973126851056
# [07:01:58] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [07:01:58] Linear model: C = 1e-05 score = -1.438191227658049
# [07:01:59] Linear model: C = 5e-05 score = -1.4019897536854127
# [07:01:59] Linear model: C = 0.0001 score = -1.3952796816717878
# [07:02:00] Linear model: C = 0.0005 score = -1.3894901680917289
# [07:02:00] Linear model: C = 0.001 score = -1.3899917842589573
# [07:02:00] Linear model: C = 0.005 score = -1.3903829345998953
# [07:02:00] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [07:02:01] Linear model: C = 1e-05 score = -1.4446976112229122
# [07:02:01] Linear model: C = 5e-05 score = -1.4034540155704347
# [07:02:02] Linear model: C = 0.0001 score = -1.3955919089801563
# [07:02:02] Linear model: C = 0.0005 score = -1.3894570444353072
# [07:02:03] Linear model: C = 0.001 score = -1.389669673746089
# [07:02:03] Linear model: C = 0.005 score = -1.390777901030577
# [07:02:03] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [07:07:49] Training until validation scores don't improve for 100 rounds
# [07:07:59] [100]	valid's l2: 1.23372
# [07:08:04] Early stopping, best iteration is:
# [49]	valid's l2: 1.22858
# [07:08:04] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [07:08:06] Training until validation scores don't improve for 100 rounds
# [07:08:15] [100]	valid's l2: 1.25602
# [07:08:20] Early stopping, best iteration is:
# [46]	valid's l2: 1.24338
# [07:08:20] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [07:08:21] Training until validation scores don't improve for 100 rounds
# [07:08:31] [100]	valid's l2: 1.25715
# [07:08:41] [200]	valid's l2: 1.25038
# [07:08:50] [300]	valid's l2: 1.24908
# [07:09:00] [400]	valid's l2: 1.2494
# [07:09:10] [500]	valid's l2: 1.24804
# [07:09:19] [600]	valid's l2: 1.24739
# [07:09:29] [700]	valid's l2: 1.24717
# [07:09:39] [800]	valid's l2: 1.24676
# [07:09:48] [900]	valid's l2: 1.24646
# [07:09:58] [1000]	valid's l2: 1.2463
# [07:10:08] [1100]	valid's l2: 1.24628
# [07:10:10] Early stopping, best iteration is:
# [1012]	valid's l2: 1.24617
# [07:10:12] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1.2345392216222537
# [07:10:12] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [07:10:12] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 1.00 secs
# [07:10:14] Training until validation scores don't improve for 100 rounds
# [07:10:24] [100]	valid's l2: 1.22752
# [07:10:29] Early stopping, best iteration is:
# [60]	valid's l2: 1.2225
# [07:10:29] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.2225013210803213 in 0:00:16.657775
# [07:10:29] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [07:10:29] The set of hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -1.2225 mse
# [07:10:29] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [07:10:29] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# [07:10:29] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [07:10:30] Training until validation scores don't improve for 100 rounds
# [07:10:41] [100]	valid's l2: 1.23094
# [07:10:46] Early stopping, best iteration is:
# [49]	valid's l2: 1.22352
# [07:10:46] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [07:10:47] Training until validation scores don't improve for 100 rounds
# [07:10:57] [100]	valid's l2: 1.22392
# [07:11:01] Early stopping, best iteration is:
# [49]	valid's l2: 1.21906
# [07:11:02] ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [07:11:03] Training until validation scores don't improve for 100 rounds
# [07:11:14] [100]	valid's l2: 1.22181
# [07:11:19] Early stopping, best iteration is:
# [49]	valid's l2: 1.21486
# [07:11:19] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [07:11:20] Training until validation scores don't improve for 100 rounds
# [07:11:30] [100]	valid's l2: 1.24764
# [07:11:34] Early stopping, best iteration is:
# [45]	valid's l2: 1.23206
# [07:11:34] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [07:11:36] Training until validation scores don't improve for 100 rounds
# [07:11:46] [100]	valid's l2: 1.24975
# [07:11:51] Early stopping, best iteration is:
# [49]	valid's l2: 1.24448
# [07:11:51] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -1.2267962696222057
# [07:11:51] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [07:11:51] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [07:11:51] Training params: {'task_type': 'CPU', 'thread_count': 4, 'random_seed': 42, 'num_trees': 2000, 'learning_rate': 0.05, 'l2_leaf_reg': 0.01, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 
# [07:38:14] 2300:	learn: 1.1116881	test: 1.1340219	best: 1.1340219 (2300)	total: 1m 56s	remaining: 35.3s
# [07:38:19] 2400:	learn: 1.1112863	test: 1.1339177	best: 1.1339177 (2400)	total: 2m 1s	remaining: 30.3s
# [07:38:24] 2500:	learn: 1.1108704	test: 1.1337470	best: 1.1337414 (2498)	total: 2m 6s	remaining: 25.3s
# [07:38:29] 2600:	learn: 1.1104352	test: 1.1335582	best: 1.1335509 (2596)	total: 2m 11s	remaining: 20.2s
# [07:38:34] 2700:	learn: 1.1100530	test: 1.1334653	best: 1.1334652 (2691)	total: 2m 17s	remaining: 15.2s
# [07:38:40] 2800:	learn: 1.1096769	test: 1.1333470	best: 1.1333454 (2798)	total: 2m 22s	remaining: 10.1s
# [07:38:45] 2900:	learn: 1.1093780	test: 1.1332386	best: 1.1332356 (2897)	total: 2m 27s	remaining: 5.04s
# [07:38:50] 2999:	learn: 1.1090418	test: 1.1330819	best: 1.1330789 (2998)	total: 2m 32s	remaining: 0us
# [07:38:50] bestTest = 1.133078934
# [07:38:50] bestIteration = 2998
# [07:38:50] Shrink model to first 2999 iterations.
# [07:38:50] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1.262914073764358
# [07:38:50] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [07:38:50] Time left 1355.31 secs
#
# [07:38:50] Layer 1 training completed.
#
# [07:38:50] Blending: optimization starts with equal weights and score -1.2199327031311233
# [07:38:51] Blending: iteration 0: score = -1.2150996114485857, weights = [0.05939149 0.2997393  0.32884896 0.12195408 0.19006613]
# [07:38:51] Blending: iteration 1: score = -1.214787177312003, weights = [0.05455999 0.28154275 0.35863063 0.07623281 0.22903381]
# [07:38:52] Blending: iteration 2: score = -1.2143816198252515, weights = [0.05416885 0.27436313 0.3568588  0.         0.3146092 ]
# [07:38:52] Blending: iteration 3: score = -1.214358608997941, weights = [0.05798107 0.27827874 0.36323857 0.         0.30050164]
# [07:38:52] Blending: iteration 4: score = -1.2143584635248048, weights = [0.05739786 0.27765658 0.36453903 0.         0.30040652]
# [07:38:52] Automl preset training completed in 2246.70 seconds
#
# [07:38:52] Model description:
# Final prediction for new objects (level 0) =
# 	 0.05740 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.27766 * (5 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM) +
# 	 0.36454 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.30041 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
#
# CPU times: user 1h 47min 7s, sys: 2min, total: 1h 49min 8s
# Wall time: 37min 26s

# %%
# Проверям
test_predict = automl.predict(y_data)
test_predict.data[:10], test_predict.shape
# Out:
# (array([[4.767848 ],
#         [8.011461 ],
#         [9.076714 ],
#         [5.7184134],
#         [9.528173 ],
#         [7.438239 ],
#         [9.821075 ],
#         [9.259719 ],
#         [9.591278 ],
#         [9.738569 ]], dtype=float32),
#  (77361, 1))

# %%
print(f'MAPE счет: {(mean_absolute_percentage_error(y_data[TARGET_NAME].values, test_predict.data[:, 0]))}')
# Out:
# MAPE счет: 0.11529742645319241

# %%
# %%time
# Задаем параметры модели
automl_ut = TabularUtilizedAutoML(task = task, 
                       timeout = 3600,
                       cpu_limit = 4,
                       reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                       general_params = {"nested_cv":False, "use_algos":[["linear_l1", "lgb", "lgb_tuned"]]}
)

# Обучаем модель
oof_pred_ut = automl_ut.fit_predict(X_data, roles = roles, verbose = 4)
# Out:
# [07:39:07] Start automl utilizator with listed constraints:
# [07:39:07] - time: 3600.00 seconds
# [07:39:07] - CPU: 4 cores
# [07:39:07] - memory: 16 GB
#
# [07:39:07] If one preset completes earlier, next preset configuration will be started
#
# [07:39:07] ==================================================
# [07:39:07] Start 0 automl preset configuration:
# [07:39:07] conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [07:39:07] Found reader_params in kwargs, need to combine
# [07:39:07] Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 42}
# [07:39:07] Found general_params in kwargs, need to combine
# [07:39:07] Merged variant for general_params = {'nested_cv': False, 'use_algos': [['linear_l1', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [07:39:07] Stdout logging level is DEBUG.
# [07:39:07] Task: reg
#
# [07:39:07] Start automl preset with listed constraints:
# [07:39:07] - time: 3599.99 seconds
# [07:39:07] - CPU: 4 cores
# [07:39:07] - memory: 16 GB
#
# [07:39:07] Train data shape: (309442, 49)
#
# [07:39:14] Feats was rejected during automatic roles guess: []
# [07:39:14] Layer 1 train process start. Time left 3592.79 secs
# [07:39:36] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [07:39:36] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 128, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 2000, 'early_stopping_rounds': 100, 'random_state': 42}
# [07:39:36] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:39:37] Training until validation scores don't improve for 100 rounds
# [07:39:48] [100]	valid's l2: 1.23831
# [07:39:53] Early stopping, best iteration is:
# [52]	valid's l2: 1.23487
# [07:39:53] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:39:54] Training until validation scores don't improve for 100 rounds
# [07:40:03] [100]	valid's l2: 1.23374
# [07:40:13] [200]	valid's l2: 1.22596
# [07:40:23] [300]	valid's l2: 1.22437
# [07:40:32] [400]	valid's l2: 1.22277
# [07:40:42] [500]	valid's l2: 1.22224
# [07:40:52] [600]	valid's l2: 1.22137
# [07:41:01] [700]	valid's l2: 1.22108
# [07:41:11] [800]	valid's l2: 1.22101
# [07:41:21] [900]	valid's l2: 1.22062
# [07:41:31] [1000]	valid's l2: 1.22055
# [07:41:40] [1100]	valid's l2: 1.22021
# [07:41:50] [1200]	valid's l2: 1.21989
# [07:42:00] [1300]	valid's l2: 1.21992
# [07:42:04] Early stopping, best iteration is:
# [1242]	valid's l2: 1.21969
# [07:42:08] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:42:10] Training until validation scores don't improve for 100 rounds
# [07:42:20] [100]	valid's l2: 1.23372
# [07:42:25] Early stopping, best iteration is:
# [49]	valid's l2: 1.22858
# [07:42:25] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:42:26] Training until validation scores don't improve for 100 rounds
# [07:42:36] [100]	valid's l2: 1.25602
# [07:42:40] Early stopping, best iteration is:
# [46]	valid's l2: 1.24338
# [07:42:40] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:42:41] Training until validation scores don't improve for 100 rounds
# [07:42:51] [100]	valid's l2: 1.25715
# [07:43:01] [200]	valid's l2: 1.25038
# [07:43:10] [300]	valid's l2: 1.24908
# [07:43:20] [400]	valid's l2: 1.2494
# [07:43:30] [500]	valid's l2: 1.24804
# [07:43:39] [600]	valid's l2: 1.24739
# [07:43:48] [700]	valid's l2: 1.24717
# [07:43:58] [800]	valid's l2: 1.24676
# [07:44:08] [900]	valid's l2: 1.24646
# [07:44:19] [1000]	valid's l2: 1.2463
# [07:44:29] [1100]	valid's l2: 1.24628
# [07:44:30] Early stopping, best iteration is:
# [1012]	valid's l2: 1.24617
# [07:44:33] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = -1.2345392216222537
# [07:44:33] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [07:44:33] Start hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ... Time budget is 300.00 secs
# [07:44:34] Training until validation scores don't improve for 100 rounds
# [07:44:44] [100]	valid's l2: 1.22752
# [07:44:49] Early stopping, best iteration is:
# [60]	valid's l2: 1.2225
# [07:44:50] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.2225013210803213 in 0:00:16.488849
# [07:44:51] Training until validation scores don't improve for 100 rounds
# [07:45:00] [100]	valid's l2: 1.22822
# [07:45:04] Early stopping, best iteration is:
# [62]	valid's l2: 1.22227
# [07:45:05] Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored -1.2222691564105659 in 0:00:14.950093
# [07:45:06] Training until validation scores don't improve for 100 rounds
# [07:45:12] [100]	valid's l2: 1.24738
# [07:45:16] Early stopping, best iteration is:
# [67]	valid's l2: 1.24307
# [07:45:16] Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored -1.2430734780483776 in 0:00:11.777098
# [07:45:18] Training until validation scores don't improve for 100 rounds
# [07:45:25] [100]	valid's l2: 1.24397
# [07:45:30] Early stopping, best iteration is:
# [64]	valid's l2: 1.23977
# [07:45:30] Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored -1.239771276270178 in 0:00:13.839900
# [07:45:31] Training until validation scores don't improve for 100 rounds
# [07:45:39] [100]	valid's l2: 1.23036
# [07:45:43] Early stopping, best iteration is:
# [59]	valid's l2: 1.22546
# [07:45:43] Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -1.2254610610165213 in 0:00:13.098332
# [07:45:44] Training until validation scores don't improve for 100 rounds
# [07:45:50] [100]	valid's l2: 1.25197
# [07:45:55] [200]	valid's l2: 1.24342
# [07:46:01] [300]	valid's l2: 1.23841
# [07:46:06] [400]	valid's l2: 1.23641
# [07:46:12] [500]	valid's l2: 1.23482
# [07:46:17] [600]	valid's l2: 1.23415
# [07:46:22] [700]	valid's l2: 1.23269
# [07:46:28] [800]	valid's l2: 1.23271
# [07:46:28] Early stopping, best iteration is:
# [714]	valid's l2: 1.23243
# [07:46:31] Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -1.2324291659058266 in 0:00:48.051129
# [07:46:33] Training until validation scores don't improve for 100 rounds
# [07:46:39] [100]	valid's l2: 1.25719
# [07:46:45] [200]	valid's l2: 1.24897
# [07:46:53] [300]	valid's l2: 1.2435
# [07:47:00] [400]	valid's l2: 1.2404
# [07:47:08] [500]	valid's l2: 1.24009
# [07:47:15] Early stopping, best iteration is:
# [483]	valid's l2: 1.23914
# [07:47:16] Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -1.2391355389992502 in 0:00:44.041737
# [07:47:17] Training until validation scores don't improve for 100 rounds
# [07:47:24] [100]	valid's l2: 1.22895
# [07:47:28] Early stopping, best iteration is:
# [64]	valid's l2: 1.22352
# [07:47:28] Trial 8 with hyperparameters {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129} scored -1.2235180432257666 in 0:00:12.682221
# [07:47:29] Training until validation scores don't improve for 100 rounds
# [07:47:38] [100]	valid's l2: 1.25082
# [07:47:46] [200]	valid's l2: 1.24228
# [07:47:55] [300]	valid's l2: 1.23622
# [07:48:04] [400]	valid's l2: 1.23466
# [07:48:13] [500]	valid's l2: 1.23387
# [07:48:22] [600]	valid's l2: 1.23288
# [07:48:32] [700]	valid's l2: 1.2315
# [07:48:41] [800]	valid's l2: 1.23037
# [07:48:50] [900]	valid's l2: 1.22973
# [07:48:59] Early stopping, best iteration is:
# [891]	valid's l2: 1.2296
# [07:49:02] Trial 9 with hyperparameters {'feature_fraction': 0.7733551396716398, 'num_leaves': 60, 'bagging_fraction': 0.9847923138822793, 'min_sum_hessian_in_leaf': 1.2604664585649468, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483} scored -1.2295964454416213 in 0:01:33.415948
# [07:49:03] Training until validation scores don't improve for 100 rounds
# [07:49:12] [100]	valid's l2: 1.228
# [07:49:17] Early stopping, best iteration is:
# [68]	valid's l2: 1.2222
# [07:49:17] Trial 10 with hyperparameters {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06} scored -1.2221997486056104 in 0:00:15.468694
# [07:49:18] Training until validation scores don't improve for 100 rounds
# [07:49:27] [100]	valid's l2: 1.23383
# [07:49:32] Early stopping, best iteration is:
# [64]	valid's l2: 1.23012
# [07:49:33] Trial 11 with hyperparameters {'feature_fraction': 0.9767330701904703, 'num_leaves': 151, 'bagging_fraction': 0.6843643863605486, 'min_sum_hessian_in_leaf': 0.0011799062523159302, 'reg_alpha': 0.005417868215013339, 'reg_lambda': 4.028557496519055e-06} scored -1.230122638860083 in 0:00:15.430954
# [07:49:34] Training until validation scores don't improve for 100 rounds
# [07:49:41] [100]	valid's l2: 1.23188
# [07:49:46] Early stopping, best iteration is:
# [61]	valid's l2: 1.22589
# [07:49:46] Trial 12 with hyperparameters {'feature_fraction': 0.5075721185513784, 'num_leaves': 181, 'bagging_fraction': 0.737571231283732, 'min_sum_hessian_in_leaf': 0.017191997180359343, 'reg_alpha': 1.385530340869224e-08, 'reg_lambda': 0.03137564187247024} scored -1.2258919309641902 in 0:00:13.226295
# [07:49:46] Hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM completed
# [07:49:46] The set of hyperparameters {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06}
#  achieve -1.2222 mse
# [07:49:46] Start fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ...
# [07:49:46] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 237, 'feature_fraction': 0.7989499894055425, 'bagging_fraction': 0.5442462510259598, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.006080390190296602}
# [07:49:46] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:49:47] Training until validation scores don't improve for 100 rounds
# [07:49:55] [100]	valid's l2: 1.23073
# [07:49:58] Early stopping, best iteration is:
# [47]	valid's l2: 1.22187
# [07:49:59] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:50:00] Training until validation scores don't improve for 100 rounds
# [07:50:08] [100]	valid's l2: 1.22835
# [07:50:13] Early stopping, best iteration is:
# [48]	valid's l2: 1.22016
# [07:50:13] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:50:14] Training until validation scores don't improve for 100 rounds
# [07:50:22] [100]	valid's l2: 1.22542
# [07:50:26] Early stopping, best iteration is:
# [50]	valid's l2: 1.21681
# [07:50:26] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:50:27] Training until validation scores don't improve for 100 rounds
# [07:50:35] [100]	valid's l2: 1.24493
# [07:50:39] Early stopping, best iteration is:
# [47]	valid's l2: 1.22952
# [07:50:39] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:50:41] Training until validation scores don't improve for 100 rounds
# [07:50:49] [100]	valid's l2: 1.24869
# [07:50:54] Early stopping, best iteration is:
# [51]	valid's l2: 1.24332
# [07:50:54] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = -1.2263353057034672
# [07:50:54] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [07:50:54] Time left 2892.99 secs
#
# [07:50:54] Layer 1 training completed.
#
# [07:50:54] Blending: optimization starts with equal weights and score -1.2228382065590466
# [07:50:54] Blending: iteration 0: score = -1.222284640869151, weights = [0.36506733 0.6349327 ]
# [07:50:54] Blending: iteration 1: score = -1.222284640869151, weights = [0.36506733 0.6349327 ]
# [07:50:54] Blending: no score update. Terminated
#
# [07:50:54] Automl preset training completed in 707.21 seconds
#
# [07:50:54] Model description:
# Final prediction for new objects (level 0) =
# 	 0.36507 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.63493 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM)
#
# [07:50:54] ==================================================
# [07:50:54] Start 1 automl preset configuration:
# [07:50:54] conf_1_sel_type_1.yml, random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# [07:50:54] Found reader_params in kwargs, need to combine
# [07:50:54] Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 43}
# [07:50:54] Found general_params in kwargs, need to combine
# [07:50:54] Merged variant for general_params = {'nested_cv': False, 'use_algos': [['linear_l1', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [07:50:54] Stdout logging level is DEBUG.
# [07:50:54] Task: reg
#
# [07:50:54] Start automl preset with listed constraints:
# [07:50:54] - time: 2892.74 seconds
# [07:50:54] - CPU: 4 cores
# [07:50:54] - memory: 16 GB
#
# [07:50:54] Train data shape: (309442, 49)
#
# [07:51:01] Feats was rejected during automatic roles guess: []
# [07:51:01] Layer 1 train process start. Time left 2886.04 secs
# [07:51:02] Training until validation scores don't improve for 100 rounds
# [07:51:08] [100]	valid's l2: 1.25984
# [07:51:15] [200]	valid's l2: 1.24991
# [07:51:23] [300]	valid's l2: 1.24435
# [07:51:30] [400]	valid's l2: 1.242
# [07:51:38] [500]	valid's l2: 1.2406
# [07:51:47] [600]	valid's l2: 1.23942
# [07:51:55] [700]	valid's l2: 1.23814
# [07:52:02] [800]	valid's l2: 1.23725
# [07:52:10] [900]	valid's l2: 1.23676
# [07:52:19] [1000]	valid's l2: 1.2363
# [07:52:27] [1100]	valid's l2: 1.23599
# [07:52:35] [1200]	valid's l2: 1.23563
# [07:52:43] [1300]	valid's l2: 1.23524
# [07:52:52] [1400]	valid's l2: 1.23504
# [07:53:00] [1500]	valid's l2: 1.23472
# [07:53:07] [1600]	valid's l2: 1.23443
# [07:53:15] [1700]	valid's l2: 1.23418
# [07:53:24] [1800]	valid's l2: 1.23409
# [07:53:32] [1900]	valid's l2: 1.23372
# [07:53:40] [2000]	valid's l2: 1.23349
# [07:53:40] Did not meet early stopping. Best iteration is:
# [1988]	valid's l2: 1.23346
# [07:53:45] Selector_LightGBM fitting and predicting completed
# [07:54:07] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [07:54:07] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 128, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 2000, 'early_stopping_rounds': 100, 'random_state': 42}
# [07:54:07] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:54:09] Training until validation scores don't improve for 100 rounds
# [07:54:18] [100]	valid's l2: 1.24362
# [07:54:24] Early stopping, best iteration is:
# [50]	valid's l2: 1.2373
# [07:54:24] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:54:25] Training until validation scores don't improve for 100 rounds
# [07:54:35] [100]	valid's l2: 1.23312
# [07:54:44] [200]	valid's l2: 1.22563
# [07:54:55] [300]	valid's l2: 1.22291
# [07:55:05] [400]	valid's l2: 1.22148
# [07:55:15] [500]	valid's l2: 1.22119
# [07:55:25] [600]	valid's l2: 1.22069
# [07:55:35] [700]	valid's l2: 1.22046
# [07:55:44] [800]	valid's l2: 1.22031
# [07:55:54] [900]	valid's l2: 1.22013
# [07:55:59] Early stopping, best iteration is:
# [855]	valid's l2: 1.22005
# [07:56:02] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:56:04] Training until validation scores don't improve for 100 rounds
# [07:56:13] [100]	valid's l2: 1.24676
# [07:56:17] Early stopping, best iteration is:
# [47]	valid's l2: 1.23931
# [07:56:18] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:56:19] Training until validation scores don't improve for 100 rounds
# [07:56:29] [100]	valid's l2: 1.24608
# [07:56:34] Early stopping, best iteration is:
# [52]	valid's l2: 1.24117
# [07:56:34] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [07:56:35] Training until validation scores don't improve for 100 rounds
# [07:56:45] [100]	valid's l2: 1.24957
# [07:56:50] Early stopping, best iteration is:
# [49]	valid's l2: 1.24545
# [07:56:50] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = -1.2366540456396629
# [07:56:50] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [07:56:50] Start hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ... Time budget is 1.00 secs
# [07:56:51] Training until validation scores don't improve for 100 rounds
# [07:57:01] [100]	valid's l2: 1.23086
# [07:57:07] Early stopping, best iteration is:
# [59]	valid's l2: 1.22353
# [07:57:07] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.2235307320231235 in 0:00:17.087418
# [07:57:07] Hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM completed
# [07:57:07] The set of hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -1.2235 mse
# [07:57:07] Start fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ...
# [07:57:07] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# [07:57:07] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:57:08] Training until validation scores don't improve for 100 rounds
# [07:57:17] [100]	valid's l2: 1.23214
# [07:57:22] Early stopping, best iteration is:
# [48]	valid's l2: 1.22604
# [07:57:22] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:57:23] Training until validation scores don't improve for 100 rounds
# [07:57:33] [100]	valid's l2: 1.22392
# [07:57:38] Early stopping, best iteration is:
# [49]	valid's l2: 1.21766
# [07:57:38] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:57:39] Training until validation scores don't improve for 100 rounds
# [07:57:49] [100]	valid's l2: 1.23795
# [07:57:53] Early stopping, best iteration is:
# [45]	valid's l2: 1.22944
# [07:57:53] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:57:54] Training until validation scores don't improve for 100 rounds
# [07:58:05] [100]	valid's l2: 1.23497
# [07:58:09] Early stopping, best iteration is:
# [48]	valid's l2: 1.22866
# [07:58:09] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [07:58:11] Training until validation scores don't improve for 100 rounds
# [07:58:20] [100]	valid's l2: 1.24113
# [07:58:25] Early stopping, best iteration is:
# [48]	valid's l2: 1.23567
# [07:58:25] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = -1.2274939048011975
# [07:58:25] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [07:58:25] Time left 2441.76 secs
#
# [07:58:25] Layer 1 training completed.
#
# [07:58:25] Blending: optimization starts with equal weights and score -1.2271679755313143
# [07:58:25] Blending: iteration 0: score = -1.2260990264509375, weights = [0.26659846 0.73340154]
# [07:58:25] Blending: iteration 1: score = -1.2260990264509375, weights = [0.26659846 0.73340154]
# [07:58:25] Blending: no score update. Terminated
#
# [07:58:25] Automl preset training completed in 451.21 seconds
#
# [07:58:25] Model description:
# Final prediction for new objects (level 0) =
# 	 0.26660 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.73340 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM)
#
# [07:58:25] ==================================================
# [07:58:25] Start 2 automl preset configuration:
# [07:58:25] conf_2_select_mode_1_no_typ.yml, random state: {'reader_params': {'random_state': 44}, 'general_params': {'return_all_predictions': False}}
# [07:58:25] Found reader_params in kwargs, need to combine
# [07:58:25] Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 44}
# [07:58:25] Found general_params in kwargs, need to combine
# [07:58:25] Merged variant for general_params = {'nested_cv': False, 'use_algos': [['linear_l1', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [07:58:25] Stdout logging level is DEBUG.
# [07:58:25] Task: reg
#
# [07:58:25] Start automl preset with listed constraints:
# [07:58:25] - time: 2441.49 seconds
# [07:58:25] - CPU: 4 cores
# [07:58:25] - memory: 16 GB
#
# [07:58:25] Train data shape: (309442, 49)
#
# [07:58:25] Layer 1 train process start. Time left 2441.27 secs
# [07:58:27] Training until validation scores don't improve for 100 rounds
# [07:58:33] [100]	valid's l2: 1.26063
# [07:58:40] [200]	valid's l2: 1.251
# [07:58:47] [300]	valid's l2: 1.24522
# [07:58:54] [400]	valid's l2: 1.24278
# [07:59:02] [500]	valid's l2: 1.24119
# [07:59:10] [600]	valid's l2: 1.24045
# [07:59:18] [700]	valid's l2: 1.23955
# [07:59:25] [800]	valid's l2: 1.23922
# [07:59:33] [900]	valid's l2: 1.23848
# [07:59:41] [1000]	valid's l2: 1.2381
# [07:59:48] [1100]	valid's l2: 1.23788
# [07:59:56] [1200]	valid's l2: 1.23754
# [08:00:04] [1300]	valid's l2: 1.23722
# [08:00:12] [1400]	valid's l2: 1.23702
# [08:00:19] [1500]	valid's l2: 1.2367
# [08:00:27] [1600]	valid's l2: 1.2366
# [08:00:35] [1700]	valid's l2: 1.2362
# [08:00:43] [1800]	valid's l2: 1.23607
# [08:00:51] [1900]	valid's l2: 1.23593
# [08:00:58] [2000]	valid's l2: 1.23597
# [08:00:58] Did not meet early stopping. Best iteration is:
# [1943]	valid's l2: 1.2359
# [08:01:03] Selector_LightGBM fitting and predicting completed
# [08:01:03] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [08:01:03] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 128, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 2000, 'early_stopping_rounds': 100, 'random_state': 42}
# [08:01:03] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:01:04] Training until validation scores don't improve for 100 rounds
# [08:01:11] [100]	valid's l2: 1.25118
# [08:01:18] [200]	valid's l2: 1.24231
# [08:01:26] [300]	valid's l2: 1.2397
# [08:01:34] [400]	valid's l2: 1.23819
# [08:01:43] [500]	valid's l2: 1.23745
# [08:01:51] [600]	valid's l2: 1.23687
# [08:01:59] [700]	valid's l2: 1.23652
# [08:02:07] [800]	valid's l2: 1.23576
# [08:02:16] [900]	valid's l2: 1.2353
# [08:02:24] [1000]	valid's l2: 1.23513
# [08:02:32] [1100]	valid's l2: 1.23496
# [08:02:41] [1200]	valid's l2: 1.23448
# [08:02:48] [1300]	valid's l2: 1.23433
# [08:02:55] Early stopping, best iteration is:
# [1284]	valid's l2: 1.23428
# [08:03:00] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08
yperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -1.2355 mse
# [08:08:38] Start fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ...
# [08:08:38] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# [08:08:38] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:08:39] Training until validation scores don't improve for 100 rounds
# [08:08:47] [100]	valid's l2: 1.24324
# [08:08:51] Early stopping, best iteration is:
# [52]	valid's l2: 1.23787
# [08:08:51] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:08:52] Training until validation scores don't improve for 100 rounds
# [08:09:00] [100]	valid's l2: 1.24215
# [08:09:04] Early stopping, best iteration is:
# [49]	valid's l2: 1.23822
# [08:09:04] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:09:05] Training until validation scores don't improve for 100 rounds
# [08:09:12] [100]	valid's l2: 1.24078
# [08:09:16] Early stopping, best iteration is:
# [46]	valid's l2: 1.23579
# [08:09:16] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:09:17] Training until validation scores don't improve for 100 rounds
# [08:09:25] [100]	valid's l2: 1.24512
# [08:09:33] [200]	valid's l2: 1.2379
# [08:09:42] [300]	valid's l2: 1.23632
# [08:09:50] [400]	valid's l2: 1.23531
# [08:09:59] [500]	valid's l2: 1.23427
# [08:10:08] [600]	valid's l2: 1.23324
# [08:10:17] [700]	valid's l2: 1.23308
# [08:10:26] [800]	valid's l2: 1.23238
# [08:10:34] [900]	valid's l2: 1.23208
# [08:10:43] [1000]	valid's l2: 1.23187
# [08:10:51] [1100]	valid's l2: 1.23161
# [08:11:01] [1200]	valid's l2: 1.23153
# [08:11:10] [1300]	valid's l2: 1.23129
# [08:11:18] [1400]	valid's l2: 1.23125
# [08:11:27] [1500]	valid's l2: 1.23079
# [08:11:36] [1600]	valid's l2: 1.23067
# [08:11:45] [1700]	valid's l2: 1.23069
# [08:11:49] Early stopping, best iteration is:
# [1650]	valid's l2: 1.23059
# [08:11:56] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:11:57] Training until validation scores don't improve for 100 rounds
# [08:12:05] [100]	valid's l2: 1.23366
# [08:12:09] Early stopping, best iteration is:
# [47]	valid's l2: 1.22717
# [08:12:09] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = -1.2339289879305386
# [08:12:09] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [08:12:09] Time left 1617.61 secs
#
# [08:12:09] Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# [08:12:09] Layer 1 training completed.
#
# [08:12:09] Blending: optimization starts with equal weights and score -1.2236655703989465
# [08:12:09] Blending: iteration 0: score = -1.223663076452509, weights = [0.5079175  0.49208248]
# [08:12:09] Blending: iteration 1: score = -1.223663076452509, weights = [0.5079175  0.49208248]
# [08:12:09] Blending: no score update. Terminated
#
# [08:12:09] Automl preset training completed in 824.13 seconds
#
# [08:12:09] Model description:
# Final prediction for new objects (level 0) =
# 	 0.50792 * (4 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.49208 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGB
===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:17:43] Training until validation scores don't improve for 100 rounds
# [08:17:51] [100]	valid's l2: 1.2493
# [08:17:55] Early stopping, best iteration is:
# [48]	valid's l2: 1.24476
# [08:17:55] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:17:56] Training until validation scores don't improve for 100 rounds
# [08:18:04] [100]	valid's l2: 1.2537
# [08:18:09] Early stopping, best iteration is:
# [51]	valid's l2: 1.2494
# [08:18:09] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:18:10] Training until validation scores don't improve for 100 rounds
# [08:18:18] [100]	valid's l2: 1.24062
# [08:18:22] Early stopping, best iteration is:
# [48]	valid's l2: 1.23312
# [08:18:23] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:18:23] Training until validation scores don't improve for 100 rounds
# [08:18:32] [100]	valid's l2: 1.2528
# [08:18:36] Early stopping, best iteration is:
# [49]	valid's l2: 1.24614
# [08:18:36] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = -1.237627969865151
# [08:18:36] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [08:18:36] Start hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ... Time budget is 1.00 secs
# [08:18:37] Training until validation scores don't improve for 100 rounds
# [08:18:46] [100]	valid's l2: 1.22415
# [08:18:51] Early stopping, best iteration is:
# [61]	valid's l2: 1.22167
# [08:18:51] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.221672344902436 in 0:00:14.968926
# [08:18:51] Hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM completed
# [08:18:51] The set of hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -1.2217 mse
# [08:18:51] Start fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ...
# [08:18:51] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# [08:18:51] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:18:52] Training until validation scores don't improve for 100 rounds
# [08:19:00] [100]	valid's l2: 1.22358
# [08:19:05] Early stopping, best iteration is:
# [52]	valid's l2: 1.22015
# [08:19:05] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:19:06] Training until validation scores don't improve for 100 rounds
# [08:19:14] [100]	valid's l2: 1.24169
# [08:19:19] Early stopping, best iteration is:
# [48]	valid's l2: 1.23605
# [08:19:19] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:19:20] Training until validation scores don't improve for 100 rounds
# [08:19:28] [100]	valid's l2: 1.24577
# [08:19:32] Early stopping, best iteration is:
# [48]	valid's l2: 1.23996
# [08:19:32] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:19:33] Training until validation scores don't improve for 100 rounds
# [08:19:42] [100]	valid's l2: 1.2315
# [08:19:46] Early stopping, best iteration is:
# [48]	valid's l2: 1.22361
# [08:19:47] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:19:48] Training until validation scores don't improve for 100 rounds
# [08:19:56] [100]	valid's l2: 1.23913
# [08:20:00] Early stopping, best iteration is:
# [48]	valid's l2: 1.23439
# [08:20:00] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = -1.2308332119320515
# [08:20:00] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [08:20:00] Time left 1146.46 secs
#
# [08:20:00] Layer 1 training completed.
#
# [08:20:00] Blending: optimization starts with equal weights and score -1.2292540988484049
# [08:20:00] Blending: iteration 0: score = -1.2286742659399237, weights = [0.32933396 0.67066604]
# [08:20:01] Blending: iteration 1: score = -1.2286742659399237, weights = [0.32933396 0.67066604]
# [08:20:01] Blending: no score update. Terminated
#
# [08:20:01] Automl preset training completed in 471.10 seconds
#
# [08:20:01] Model description:
# Final prediction for new objects (level 0) =
# 	 0.32933 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.67067 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM)
#
# [08:20:01] ==================================================
# [08:20:01] Start 4 automl preset configuration:
# [08:20:01] conf_4_sel_type_0_no_int.yml, random state: {'reader_params': {'random_state': 46}, 'general_params': {'return_all_predictions': False}}
# [08:20:01] Found reader_params in kwargs, need to combine
# [08:20:01] Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 46}
# [08:20:01] Found general_params in kwargs, need to combine
# [08:20:01] Merged variant for general_params = {'nested_cv': False, 'use_algos': [['linear_l1', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [08:20:01] Stdout logging level is DEBUG.
# [08:20:01] Task: reg
#
# [08:20:01] Start automl preset with listed constraints:
# [08:20:01] - time: 1146.18 seconds
# [08:20:01] - CPU: 4 cores
# [08:20:01] - memory: 16 GB
#
# [08:20:01] Train data shape: (309442, 49)
#
# [08:20:07] Feats was rejected during automatic roles guess: []
# [08:20:07] Layer 1 train process start. Time left 1139.50 secs
# [08:20:09] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [08:20:09] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 128, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 2000, 'early_stopping_rounds': 100, 'random_state': 42}
# [08:20:09] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:20:10] Training until validation scores don't improve for 100 rounds
# [08:20:19] [100]	valid's l2: 1.23707
# [08:20:27] [200]	valid's l2: 1.22953
# [08:20:36] [300]	valid's l2: 1.22649
# [08:20:45] [400]	valid's l2: 1.22465
# [08:20:54] [500]	valid's l2: 1.22342
# [08:21:03] [600]	valid's l2: 1.22231
# [08:21:12] [700]	valid's l2: 1.22158
# [08:21:21] [800]	valid's l2: 1.22128
# [08:21:30] [900]	valid's l2: 1.22081
# [08:21:39] [1000]	valid's l2: 1.22052
# [08:21:47] [1100]	valid's l2: 1.22026
# [08:21:56] [1200]	valid's l2: 1.21994
# [08:22:05] [1300]	valid's l2: 1.21968
# [08:22:14] [1400]	valid's l2: 1.21954
# [08:22:24] [1500]	valid's l2: 1.2192
# [08:22:32] [1600]	valid's l2: 1.21918
# [08:22:33] Early stopping, best iteration is:
# [1509]	valid's l2: 1.21911
# [08:22:38] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:22:39] Training until validation scores don't improve for 100 rounds
# [08:22:47] [100]	valid's l2: 1.25702
# [08:22:51] Early stopping, best iteration is:
# [50]	valid's l2: 1.25106
# [08:22:51] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:22:53] Training until validation scores don't improve for 100 rounds
# [08:23:01] [100]	valid's l2: 1.24263
# [08:23:09] [200]	valid's l2: 1.23534
# [08:23:18] [300]	valid's l2: 1.23255
# [08:23:28] [400]	valid's l2: 1.23088
# [08:23:36] [500]	valid's l2: 1.23005
# [08:23:45] [600]	valid's l2: 1.22971
# [08:23:54] [700]	valid's l2: 1.22918
# [08:24:03] [800]	valid's l2: 1.22865
# [08:24:12] [900]	valid's l2: 1.22825
# [08:24:20] [1000]	valid's l2: 1.22792
# [08:24:30] [1100]	valid's l2: 1.2274
# [08:24:38] [1200]	valid's l2: 1.22719
# [08:24:47] [1300]	valid's l2: 1.22715
# [08:24:56] [1400]	valid's l2: 1.22719
# [08:24:59] Early stopping, best iteration is:
# [1327]	valid's l2: 1.22698
# [08:25:03] Time limit exceeded after calculating fold 2
#
# [08:25:04] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = -1.2323860402332525
# [08:25:04] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [08:25:04] Start hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ... Time budget is 1.00 secs
# [08:25:05] Training until validation scores don't improve for 100 rounds
# [08:25:15] [100]	valid's l2: 1.22498
# [08:25:20] Early stopping, best iteration is:
# [59]	valid's l2: 1.22001
# [08:25:20] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.2200086293844532 in 0:00:16.113477
# [08:25:20] Hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM completed
# [08:25:20] The set of hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -1.2200 mse
# [08:25:20] Start fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ...
# [08:25:20] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# [08:25:20] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:25:21] Training until validation scores don't improve for 100 rounds
# [08:25:30] [100]	valid's l2: 1.22742
# [08:25:34] Early stopping, best iteration is:
# [48]	valid's l2: 1.22121
# [08:25:34] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:25:35] Training until validation scores don't improve for 100 rounds
# [08:25:43] [100]	valid's l2: 1.24825
# [08:25:47] Early stopping, best iteration is:
# [48]	valid's l2: 1.24259
# [08:25:48] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:25:49] Training until validation scores don't improve for 100 rounds
# [08:25:57] [100]	valid's l2: 1.23468
# [08:26:06] [200]	valid's l2: 1.22888
# [08:26:15] [300]	valid's l2: 1.22762
# [08:26:23] [400]	valid's l2: 1.22649
# [08:26:33] [500]	valid's l2: 1.22556
# [08:26:42] [600]	valid's l2: 1.2254
# [08:26:51] [700]	valid's l2: 1.22545
# [08:26:51] Early stopping, best iteration is:
# [608]	valid's l2: 1.22532
# [08:26:54] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:26:55] Training until validation scores don't improve for 100 rounds
# [08:27:04] [100]	valid's l2: 1.23685
# [08:27:08] Early stopping, best iteration is:
# [48]	valid's l2: 1.23024
# [08:27:08] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM =====
# [08:27:09] Training until validation scores don't improve for 100 rounds
# [08:27:17] [100]	valid's l2: 1.2355
# [08:27:22] Early stopping, best iteration is:
# [50]	valid's l2: 1.22974
# [08:27:22] Fitting Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM finished. score = -1.2298184805286505
# [08:27:22] Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM fitting and predicting completed
# [08:27:22] Time left 704.87 secs
#
# [08:27:22] Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# [08:27:22] Layer 1 training completed.
#
# [08:27:22] Blending: optimization starts with equal weights and score -1.2259401938722791
# [08:27:22] Blending: iteration 0: score = -1.2259056362945469, weights = [0.45704788 0.5429521 ]
# [08:27:22] Blending: iteration 1: score = -1.2259056362945469, weights = [0.45704788 0.5429521 ]
# [08:27:22] Blending: no score update. Terminated
#
# [08:27:22] Automl preset training completed in 441.60 seconds
#
# [08:27:22] Model description:
# Final prediction for new objects (level 0) =
# 	 0.45705 * (3 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.54295 * (5 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM)
#
# [08:27:22] ==================================================
# [08:27:22] Start 5 automl preset configuration:
# [08:27:22] conf_5_sel_type_1_tuning_full.yml, random state: {'reader_params': {'random_state': 47}, 'general_params': {'return_all_predictions': False}}
# [08:27:22] Found reader_params in kwargs, need to combine
# [08:27:22] Merged variant for reader_params = {'n_jobs': 4, 'cv': 5, 'random_state': 47}
# [08:27:22] Found general_params in kwargs, need to combine
# [08:27:22] Merged variant for general_params = {'nested_cv': False, 'use_algos': [['linear_l1', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# [08:27:22] Stdout logging level is DEBUG.
# [08:27:22] Task: reg
#
# [08:27:22] Start automl preset with listed constraints:
# [08:27:22] - time: 704.55 seconds
# [08:27:22] - CPU: 4 cores
# [08:27:22] - memory: 16 GB
#
# [08:27:22] Train data shape: (309442, 49)
#
# [08:27:29] Feats was rejected during automatic roles guess: []
# [08:27:29] Layer 1 train process start. Time left 697.97 secs
# [08:27:30] Training until validation scores don't improve for 100 rounds
# [08:27:37] [100]	valid's l2: 1.2629
# [08:27:43] [200]	valid's l2: 1.25096
# [08:27:50] [300]	valid's l2: 1.24484
# [08:27:57] [400]	valid's l2: 1.24201
# [08:28:05] [500]	valid's l2: 1.24037
# [08:28:13] [600]	valid's l2: 1.23938
# [08:28:20] [700]	valid's l2: 1.23894
# [08:28:28] [800]	valid's l2: 1.23853
# [08:28:36] [900]	valid's l2: 1.23824
# [08:28:43] [1000]	valid's l2: 1.23778
# [08:28:51] [1100]	valid's l2: 1.23741
# [08:28:59] [1200]	valid's l2: 1.23675
# [08:29:07] [1300]	valid's l2: 1.23628
# [08:29:14] [1400]	valid's l2: 1.23581
# [08:29:22] [1500]	valid's l2: 1.23553
# [08:29:30] [1600]	valid's l2: 1.23535
# [08:29:38] [1700]	valid's l2: 1.23528
# [08:29:46] [1800]	valid's l2: 1.23503
# [08:29:53] [1900]	valid's l2: 1.23476
# [08:30:01] [2000]	valid's l2: 1.23471
# [08:30:01] Did not meet early stopping. Best iteration is:
# [1996]	valid's l2: 1.23471
# [08:30:07] Selector_LightGBM fitting and predicting completed
# [08:30:29] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [08:30:29] Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 128, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 4, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 2000, 'early_stopping_rounds': 100, 'random_state': 42}
# [08:30:29] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:30:30] Training until validation scores don't improve for 100 rounds
# [08:30:40] [100]	valid's l2: 1.24591
# [08:30:45] Early stopping, best iteration is:
# [47]	valid's l2: 1.23918
# [08:30:45] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:30:46] Training until validation scores don't improve for 100 rounds
# [08:30:55] [100]	valid's l2: 1.25961
# [08:31:00] Early stopping, best iteration is:
# [49]	valid's l2: 1.25461
# [08:31:00] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:31:01] Training until validation scores don't improve for 100 rounds
# [08:31:11] [100]	valid's l2: 1.2429
# [08:31:21] [200]	valid's l2: 1.23557
# [08:31:30] [300]	valid's l2: 1.23327
# [08:31:40] [400]	valid's l2: 1.23178
# [08:31:50] [500]	valid's l2: 1.23191
# [08:31:51] Early stopping, best iteration is:
# [414]	valid's l2: 1.23162
# [08:31:53] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [08:31:54] Training until validation scores don't improve for 100 rounds
# [08:32:03] [100]	valid's l2: 1.23677
# [08:32:14] [200]	valid's l2: 1.22726
# [08:32:23] [300]	valid's l2: 1.22457
# [08:32:34] [400]	valid's l2: 1.2236
# [08:32:43] [500]	valid's l2: 1.22315
# [08:32:53] [600]	valid's l2: 1.22253
# [08:33:03] [700]	valid's l2: 1.22198
# [08:33:12] [800]	valid's l2: 1.22155
# [08:33:22] Early stopping, best iteration is:
# [798]	valid's l2: 1.2215
# [08:33:25] Time limit exceeded after calculating fold 3
#
# [08:33:25] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = -1.2367290550917007
# [08:33:25] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [08:33:25] Time left 342.22 secs
#
# [08:33:25] Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# [08:33:25] Layer 1 training completed.
#
# [08:33:25] Automl preset training completed in 362.33 seconds
#
# [08:33:25] Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (4 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM)
#
# [08:33:25] ==================================================
# [08:33:25] Blending: optimization starts with equal weights and score -1.2145574043196552
# [08:33:25] Blending: iteration 0: score = -1.2129157734438891, weights = [0.16892985 0.         0.42343566 0.         0.24539399 0.16224045]
# [08:33:26] Blending: iteration 1: score = -1.2125215188586047, weights = [0.25795177 0.06650256 0.36954802 0.         0.17974938 0.12624831]
# [08:33:26] Blending: iteration 2: score = -1.2125206964351847, weights = [0.25466123 0.07251059 0.36863828 0.         0.17903545 0.12515439]
# [08:33:27] Blending: iteration 3: score = -1.2125205746104213, weights = [0.25220963 0.07487015 0.36835733 0.         0.17889905 0.12566389]
# [08:33:28] Blending: iteration 4: score = -1.2125205847860563, weights = [0.25173494 0.07491768 0.36859116 0.         0.17901261 0.12574367]
# CPU times: user 2h 29min 46s, sys: 32.8 s, total: 2h 30min 19s
# Wall time: 54min 20s

# %%
# Проверяем
test_predict_ut = automl_ut.predict(y_data)
test_predict_ut.data[:10], test_predict_ut.shape
# Out:
# (array([[4.552096 ],
#         [8.0315485],
#         [9.028978 ],
#         [5.6263   ],
#         [9.555585 ],
#         [7.3850145],
#         [9.771764 ],
#         [9.248473 ],
#         [9.556484 ],
#         [9.696133 ]], dtype=float32),
#  (77361, 1))

# %%
print(f'MAPE счет: {(mean_absolute_percentage_error(y_data[TARGET_NAME].values, test_predict_ut.data[:, 0]))}')
# Out:
# MAPE счет: 0.11446320651776393

# %%
test_data = test_data.drop(['reviewer_score'], axis=1)

# %%
# Предсказываем данные на обученной модели
predict = automl.predict(test_data)
predict.data[:10], predict.shape
# Out:
# (array([[8.842812],
#         [7.613861],
#         [8.255086],
#         [9.934059],
#         [9.683772],
#         [9.151451],
#         [7.718568],
#         [8.143415],
#         [8.416356],
#         [8.009105]], dtype=float32),
#  (128935, 1))

# %%
# Предсказываем данные на обученной модели
predict_ut = automl_ut.predict(test_data)
predict_ut.data[:10], predict_ut.shape
# Out:
# (array([[8.824211 ],
#         [7.3504395],
#         [8.171405 ],
#         [9.901618 ],
#         [9.642178 ],
#         [9.046652 ],
#         [7.679413 ],
#         [8.169362 ],
#         [8.393986 ],
#         [7.5557046]], dtype=float32),
#  (128935, 1))

# %%
# Загружаем сабмит
submission = pd.read_csv('../input/sf-booking/submission.csv')
submission.head(10), submission.shape
# Out:
# (   reviewer_score      id
#  0               1  488440
#  1              10  274649
#  2               3  374688
#  3              10  404352
#  4               9  451596
#  5              10  302161
#  6              10  317079
#  7               1   13963
#  8               4  159785
#  9              10  195089,
#  (128935, 2))

# %%
# Вставляем наши предсказанные данные с модели TabularAutoML и сохраняем 
submission[TARGET_NAME] = predict.data[:, 0]
submission.to_csv('mk+lama.csv', index = False)
submission.head(), submission.shape
# Out:
# (   reviewer_score      id
#  0           8.843  488440
#  1           7.614  274649
#  2           8.255  374688
#  3           9.934  404352
#  4           9.684  451596,
#  (128935, 2))

# %%
# Вставляем наши предсказанные данные с модели TabularUtilizedAutoML и сохраняем
submission[TARGET_NAME] = predict_ut.data[:, 0]
submission.to_csv('mk_ut+lama.csv', index = False)
submission.head(), submission.shape
# Out:
# (   reviewer_score      id
#  0           8.824  488440
#  1           7.350  274649
#  2           8.171  374688
#  3           9.902  404352
#  4           9.642  451596,
#  (128935, 2))

# %%
# %%time

# Сделаем более детальную оценку признаков top-10
accurate_fi = automl.get_feature_scores('accurate', y_data, silent = False)
accurate_fi.set_index('Feature')['Importance'][:10].plot.bar(figsize = (16, 8), grid = True)
# Out:
# [08:36:40] LightAutoML ts master used 48 feats
# [08:37:06] 1/48 Calculated score for p_review_sentiments_compound: 0.2180356
# [08:37:19] 2/48 Calculated score for negative_review_class: 0.0001189
# [08:37:33] 3/48 Calculated score for review_total_negative_word_counts: 0.0042139
# [08:37:46] 4/48 Calculated score for tag_count_nights: 0.0004606
# [08:37:59] 5/48 Calculated score for review_total_word_counts_diff_norm: 0.0218065
# [08:38:13] 6/48 Calculated score for p_review_sentiments_pos: 0.0035722
# [08:38:26] 7/48 Calculated score for total_number_of_reviews_reviewer_has_given: 0.0017759
# [08:38:39] 8/48 Calculated score for room_type_King: 0.0000069
# [08:38:52] 9/48 Calculated score for district_rating: 0.0000065
# [08:39:06] 10/48 Calculated score for reviewer_n_est: 0.0001547
# [08:39:19] 11/48 Calculated score for total_number_of_reviews: -0.0002342
# [08:39:32] 12/48 Calculated score for tag_reviewer_type_1.0: 0.0000718
# [08:39:45] 13/48 Calculated score for hotel_code: -0.0004159
# [08:39:58] 14/48 Calculated score for p_review_sentiments_neu: 0.0027192
# [08:40:12] 15/48 Calculated score for negative_review_pos: 0.0014756
# [08:40:25] 16/48 Calculated score for review_positive_word_proportion: 0.2438222
# [08:40:38] 17/48 Calculated score for afinn_score: 0.0075633
# [08:40:52] 18/48 Calculated score for positive_polarity: 0.0257139
# [08:41:05] 19/48 Calculated score for tag_reviewer_type_2.0: 0.0000003
# [08:41:18] 20/48 Calculated score for room_type_Guestroom: 0.0000009
# [08:41:31] 21/48 Calculated score for reviewer_en: 0.0001756
# [08:41:45] 22/48 Calculated score for room_type_Standard: 0.0000544
# [08:41:58] 23/48 Calculated score for tag_from_mobile: 0.0008870
# [08:42:11] 24/48 Calculated score for positive_review_class: 0.0021320
# [08:42:24] 25/48 Calculated score for positive_words_more: -0.0010095
# [08:42:37] 26/48 Calculated score for tag_view_room: 0.0000075
# [08:42:51] 27/48 Calculated score for tag_leisure_trip: 0.0021134
# [08:43:04] 28/48 Calculated score for room_type_Classic: 0.0000006
# [08:43:18] 29/48 Calculated score for room_type_Single: 0.0000088
# [08:43:33] 30/48 Calculated score for district_code: 0.0000030
# [08:43:48] 31/48 Calculated score for room_type_without Window: -0.0000078
# [08:44:01] 32/48 Calculated score for n_review_sentiments_compound: 0.0718435
# [08:44:15] 33/48 Calculated score for review_week: 0.0015402
# [08:44:28] 34/48 Calculated score for n_review_sentiments_neg: 0.0041628
# [08:44:41] 35/48 Calculated score for room_type_Deluxe: 0.0000015
# [08:44:54] 36/48 Calculated score for review_difference_with_top: 0.0051251
# [08:45:07] 37/48 Calculated score for review_total_positive_word_counts: 0.0055807
# [08:45:21] 38/48 Calculated score for negative_polarity: 0.0318722
# [08:45:34] 39/48 Calculated score for hotel_country_code: 0.0002315
# [08:45:47] 40/48 Calculated score for average_score: 0.1051699
# [08:46:01] 41/48 Calculated score for room_type_Suite: 0.0000051
# [08:46:14] 42/48 Calculated score for reviewer_resident: 0.0003350
# [08:46:27] 43/48 Calculated score for room_type_Superior: 0.0000138
# [08:46:40] 44/48 Calculated score for reviewer_nationality_cat: 0.0232812
# [08:46:54] 45/48 Calculated score for p_review_sentiments_neg: 0.0153586
# [08:47:07] 46/48 Calculated score for positive_review_pos: 0.0272880
# [08:47:20] 47/48 Calculated score for hotel_distance_to_center: 0.0062236
# [08:47:34] 48/48 Calculated score for n_review_sentiments_pos: 0.0071318
# CPU times: user 31min 23s, sys: 4.44 s, total: 31min 28s
# Wall time: 10min 53s
# <AxesSubplot:xlabel='Feature'>

# %%
# %%time

# Сделаем более детальную оценку признаков модели Utilized top-10
accurate_fi = automl_ut.get_feature_scores('accurate', y_data, silent = False)
accurate_fi.set_index('Feature')['Importance'][:10].plot.bar(figsize = (16, 8), grid = True)
# Out:
# [08:47:34] LightAutoML ts master used 48 feats
# [08:49:41] 1/48 Calculated score for p_review_sentiments_compound: 0.2130195
# [08:50:45] 2/48 Calculated score for negative_review_class: 0.0002499
# [08:51:49] 3/48 Calculated score for review_total_negative_word_counts: 0.0032636
# [08:52:52] 4/48 Calculated score for tag_count_nights: 0.0008828
# [08:53:55] 5/48 Calculated score for review_total_word_counts_diff_norm: 0.0226117
# [08:54:57] 6/48 Calculated score for p_review_sentiments_pos: 0.0030964
# [08:56:00] 7/48 Calculated score for total_number_of_reviews_reviewer_has_given: 0.0017865
# [08:57:03] 8/48 Calculated score for room_type_King: 0.0000122
# [08:58:06] 9/48 Calculated score for district_rating: -0.0000816
# [08:59:08] 10/48 Calculated score for reviewer_n_est: 0.0010028
# [09:00:11] 11/48 Calculated score for total_number_of_reviews: -0.0000893
# [09:01:14] 12/48 Calculated score for tag_reviewer_type_1.0: 0.0001310
# [09:02:18] 13/48 Calculated score for hotel_code: -0.0007548
# [09:03:20] 14/48 Calculated score for p_review_sentiments_neu: 0.0039851
# [09:04:23] 15/48 Calculated score for negative_review_pos: 0.0035212
# [09:05:26] 16/48 Calculated score for review_positive_word_proportion: 0.3454134
# [09:06:28] 17/48 Calculated score for afinn_score: 0.0083343
# [09:07:31] 18/48 Calculated score for positive_polarity: 0.0233060
# [09:08:34] 19/48 Calculated score for tag_reviewer_type_2.0: -0.0000134
# [09:09:37] 20/48 Calculated score for room_type_Guestroom: -0.0000013
# [09:10:40] 21/48 Calculated score for reviewer_en: 0.0019968
# [09:11:43] 22/48 Calculated score for room_type_Standard: 0.0001073
# [09:12:46] 23/48 Calculated score for tag_from_mobile: 0.0007964
# [09:13:51] 24/48 Calculated score for positive_review_class: 0.0007566
# [09:14:55] 25/48 Calculated score for positive_words_more: -0.0008415
# [09:16:00] 26/48 Calculated score for tag_view_room: 0.0000410
# [09:17:04] 27/48 Calculated score for tag_leisure_trip: 0.0035691
# [09:18:10] 28/48 Calculated score for room_type_Classic: -0.0000021
# [09:19:15] 29/48 Calculated score for room_type_Single: 0.0000074
# [09:20:20] 30/48 Calculated score for district_code: 0.0001226
# [09:21:24] 31/48 Calculated score for room_type_without Window: 0.0000335
# [09:22:29] 32/48 Calculated score for n_review_sentiments_compound: 0.0507216
# [09:23:33] 33/48 Calculated score for review_week: 0.0023240
# [09:24:38] 34/48 Calculated score for n_review_sentiments_neg: 0.0047044
# [09:25:44] 35/48 Calculated score for room_type_Deluxe: 0.0000190
# [09:26:48] 36/48 Calculated score for review_difference_with_top: 0.0024626
# [09:27:53] 37/48 Calculated score for review_total_positive_word_counts: 0.0052220
# [09:28:57] 38/48 Calculated score for negative_polarity: 0.0234565
# [09:30:01] 39/48 Calculated score for hotel_country_code: 0.0004540
# [09:31:05] 40/48 Calculated score for average_score: 0.1384382
# [09:32:09] 41/48 Calculated score for room_type_Suite: 0.0000296
# [09:33:12] 42/48 Calculated score for reviewer_resident: 0.0005587
# [09:34:16] 43/48 Calculated score for room_type_Superior: 0.0000100
# [09:35:22] 44/48 Calculated score for reviewer_nationality_cat: 0.0146139
# [09:36:28] 45/48 Calculated score for p_review_sentiments_neg: 0.0199821
# [09:37:36] 46/48 Calculated score for positive_review_pos: 0.0325430
# [09:38:49] 47/48 Calculated score for hotel_distance_to_center: 0.0001994
# [09:40:00] 48/48 Calculated score for n_review_sentiments_pos: 0.0179341
# CPU times: user 3h 6min 45s, sys: 9.42 s, total: 3h 6min 55s
# Wall time: 52min 25s
# <AxesSubplot:xlabel='Feature'>

# %%
final_time = dt.now(tz).strftime("%H:%M:%S")
final_time = dt.strptime(final_time, "%H:%M:%S")
res_time = final_time - start_time
print(f'На обработку данных ушло: {res_time}')
# Out:
# На обработку данных ушло: 3:07:35
